# %% [markdown]
# This notebook introduces the problem addressed in this paper:
#
#  - localizating an object in a large image
#  - foveation
#  - action (saccade)

# %%
# %run 0_parameters.ipynb
# Out:
# This notebook introduces the problem addressed in this paper:
#
#  - localizating an object in a large image
#  - foveation
#  - action (saccade)
#
#
# {'w': 28, 'minibatch_size': 100, 'train_batch_size': 50000, 'test_batch_size': 5000, 'noise_batch_size': 1000, 'mean': 0.1307, 'std': 0.3081, 'N_pic': 128, 'offset_std': 30, 'offset_max': 34, 'noise': 1.0, 'contrast': 1.0, 'sf_0': 0.2, 'B_sf': 0.3, 'N_theta': 6, 'N_azimuth': 26, 'N_eccentricity': 10, 'N_phase': 2, 'rho': 1.41, 'bias_deconv': True, 'p_dropout': 0.0, 'dim1': 500, 'dim2': 2000, 'lr': 0.001, 'do_adam': True, 'bn1_bn_momentum': 0.5, 'bn2_bn_momentum': 0.2, 'momentum': 0.1, 'epochs': 25, 'num_processes': 1, 'no_cuda': True, 'log_interval': 100, 'verbose': 1, 'filename': '../data/2019-03-27', 'seed': 2019, 'N_cv': 8, 'do_compute': True}
# Overwriting train.py
# 2019-03-28T11:51:40+01:00
#
# CPython 3.7.2
# IPython 7.4.0
#
# numpy 1.16.2
# matplotlib 3.0.3
# torch 1.0.1.post2
#
# compiler   : Clang 10.0.0 (clang-1000.11.45.5)
# system     : Darwin
# release    : 18.2.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 36
# interpreter: 64bit
# host name  : fortytwo
# Git hash   : c7c7b93617aa020855732df35d6843de3cca6d6a
# Git repo   : https://github.com/laurentperrinet/WhereIsMyMNIST
# Git branch : master

# %%
figname = '../figures/fig_params'

# %%
# %%writefile params.py
import os
import torch
from main import init, MetaML
from where import Where as ML
from what import WhatNet
        
import sys
opts = dict(filename='../data/2019-03-27', verbose=0, log_interval=0, do_compute=False  if len(sys.argv) > 1 else True)
#opts = dict(filename='debug', verbose=0, log_interval=0)

print(50*'-')
print(' parameter scan')
print(50*'-')

if True:
    args = init(**opts)
    #args.filename = '../data/2019-03-27'
    filename_train = args.filename + '_train.pt'
    if not(os.path.isfile(filename_train + '_lock')):
        open(filename_train + '_lock', 'w').close()
        print(50*'-')
        print('Default parameters')
        print(50*'-')
        from where import Where as ML
        from what import WhatNet
        ml = ML(args)
        ml.train(path=filename_train)
        # ml.main(path=args.filename)
        os.remove(filename_train + '_lock')

if True:
    args = init(**opts)
    mml = MetaML(args)
    if torch.cuda.is_available():
        mml.scan('no_cuda', [True, False])

    args = init(**opts)
    mml = MetaML(args)
    mml.scan('bias_deconv', [True, False])

results = {}
    
def update_results(results, parameter, accuracies, ci=0.01):
    from scipy.stats import beta

    if not parameter in results.keys(): results[parameter] = dict(value=[], accuracy=[], p_low=[], p_sup=[])
    for value in accuracies.keys():
        results[parameter]['value'].append(value)
        results[parameter]['accuracy'].append(accuracies[value][:-1].mean()*100)
        try:
            a1, b1, loc1, scale1 = beta.fit(accuracies[value][:-1], floc=0, fscale=1)
            p_low, p_sup = beta.ppf([ci, 1-ci], a=a1, b=b1)
            #print(p_low, p_sup)
            results[parameter]['p_low'].append(p_low*100)
            results[parameter]['p_sup'].append(p_sup*100)
        except:
            results[parameter]['p_low'].append(accuracies[value][:-1].mean()*100)
            results[parameter]['p_sup'].append(accuracies[value][:-1].mean()*100)
        
    return results
            
for base in [2] if not args.filename == '../data/debug' else [2]:
    print(50*'-')
    print(' base=', base)
    print(50*'-')

    print(50*'-')
    print(' parameter scan : data')
    print(50*'-')
    args = init(**opts)
    mml = MetaML(args, base=base)
    for parameter in ['sf_0', 'B_sf', 'offset_std' , 'noise']: #, 'contrast'
        accuracies = mml.parameter_scan(parameter)
        results = update_results(results, parameter, accuracies)
        
    print(50*'-')
    print(' parameter scan : network')
    print(50*'-')
    args = init(**opts)
    mml = MetaML(args)
    for parameter in ['dim1',
                      'bn1_bn_momentum',
                      'dim2',
                      'bn2_bn_momentum',
                      'p_dropout']:
        accuracies = mml.parameter_scan(parameter)
        results = update_results(results, parameter, accuracies)

    print(' parameter scan : learning ')
    args = init(**opts)
    mml = MetaML(args, base=base)
    print(50*'-')
    print('Using SGD')
    print(50*'-')
    for parameter in ['lr', 'momentum', 'minibatch_size', 'epochs']:
        mml.parameter_scan(parameter)
    print(50*'-')
    print('Using ADAM')
    print(50*'-')
    args = init(**opts)
    args.do_adam = True
    mml = MetaML(args, tag='adam')
    for parameter in ['lr', 'momentum', 'minibatch_size', 'epochs']:
        accuracies = mml.parameter_scan(parameter)
        results = update_results(results, parameter, accuracies)

    print(50*'-')
    print(' parameter scan : retina')
    print(50*'-')
    args = init(**opts)
    mml = MetaML(args)
    for parameter in ['N_theta',
                      'N_azimuth',
                      'N_eccentricity',
                      'rho']:
        accuracies = mml.parameter_scan(parameter)
        results = update_results(results, parameter, accuracies)
# Out:
# Overwriting params.py

# %% [raw]
# %rm -fr ../data/_tmp_scanning

# %%
# %run params.py scan
# Out:
# --------------------------------------------------
#  parameter scan
# --------------------------------------------------
# --------------------------------------------------
# Default parameters
# --------------------------------------------------
# Loading accuracy... min, max= 0.0145 0.9852
# Loading file ../data/2019-03-27_train.pt
# scanning over bias_deconv = [True, False]
# For parameter bias_deconv = True ,  Accuracy=72.7% +/- 0.3%  in 13946.4 seconds
# For parameter bias_deconv = False ,  Accuracy=73.2% +/- 0.0%  in 11114.9 seconds
# --------------------------------------------------
#  base= 2
# --------------------------------------------------
# --------------------------------------------------
#  parameter scan : data
# --------------------------------------------------
# scanning over sf_0 = [0.1        0.11892071 0.14142136 0.16817928 0.2        0.23784142
#  0.28284271 0.33635857 0.4       ]
# For parameter sf_0 = 0.100 ,  Accuracy=66.6% +/- 0.3%  in 12092.7 seconds
# For parameter sf_0 = 0.119 ,  Accuracy=67.3% +/- 0.1%  in 12423.9 seconds
# For parameter sf_0 = 0.141 ,  Accuracy=68.7% +/- 0.0%  in 12041.9 seconds
# For parameter sf_0 = 0.168 ,  Accuracy=71.2% +/- 0.4%  in 12207.2 seconds
# For parameter sf_0 = 0.200 ,  Accuracy=72.6% +/- 0.0%  in 10596.1 seconds
# For parameter sf_0 = 0.238 ,  Accuracy=74.1% +/- 0.0%  in 12426.5 seconds
# For parameter sf_0 = 0.283 ,  Accuracy=75.2% +/- 0.0%  in 12426.2 seconds
# For parameter sf_0 = 0.336 ,  Accuracy=76.1% +/- 0.2%  in 12727.2 seconds
# For parameter sf_0 = 0.400 ,  Accuracy=76.6% +/- 0.4%  in 12596.7 seconds
# 0.6593543479534281 0.6731567593241883
# 0.6705173371444766 0.6751281206002235
# 0.6866211153798774 0.6869288622706955
# 0.7026937037266737 0.7209630387480117
# 0.7410211297131013 0.7413288379372855
# 0.7505480513432861 0.7527002513100507
# 0.7560583105877005 0.7655564787368889
# 0.7566588732190477 0.7746601825405056
# scanning over B_sf = [0.15       0.17838107 0.21213203 0.25226892 0.3        0.35676213
#  0.42426407 0.50453785 0.6       ]
# For parameter B_sf = 0.150 ,  Accuracy=73.0% +/- 0.0%  in 12260.2 seconds
# For parameter B_sf = 0.178 ,  Accuracy=73.8% +/- 0.2%  in 12270.6 seconds
# For parameter B_sf = 0.212 ,  Accuracy=73.3% +/- 0.5%  in 12287.5 seconds
# For parameter B_sf = 0.252 ,  Accuracy=73.6% +/- 0.1%  in 12303.0 seconds
# For parameter B_sf = 0.300 ,  Accuracy=72.6% +/- 0.0%  in 14015.6 seconds
# For parameter B_sf = 0.357 ,  Accuracy=71.5% +/- 0.2%  in 13801.5 seconds
# For parameter B_sf = 0.424 ,  Accuracy=71.4% +/- 0.2%  in 13693.4 seconds
# For parameter B_sf = 0.505 ,  Accuracy=70.1% +/- 0.4%  in 13814.4 seconds
# For parameter B_sf = 0.600 ,  Accuracy=70.6% +/- 0.5%  in 13553.3 seconds
# 0.7287268643900804 0.7305720580106596
# 0.7345087921176268 0.7418730126403185
# 0.7216099482677696 0.7442746917518677
# 0.7336751558862322 0.7376695843935568
# 0.7254255994834812 0.7272733444713734
# 0.7103680908354786 0.7190105842959593
# 0.7098899486471536 0.7172945094443371
# 0.691372088713589 0.7108791456417984
# 0.6950689336641371 0.7161606564889054
# scanning over offset_std = [15, 17, 21, 25, 30, 35, 42, 50, 60]
# For parameter offset_std = 15 ,  Accuracy=79.8% +/- 0.1%  in 13603.6 seconds
# For parameter offset_std = 17 ,  Accuracy=78.4% +/- 0.2%  in 13432.5 seconds
# For parameter offset_std = 21 ,  Accuracy=77.2% +/- 0.1%  in 14103.1 seconds
# For parameter offset_std = 25 ,  Accuracy=73.8% +/- 0.0%  in 13917.5 seconds
# For parameter offset_std = 30 ,  Accuracy=72.6% +/- 0.0%  in 11473.2 seconds
# For parameter offset_std = 35 ,  Accuracy=71.4% +/- 0.2%  in 13972.0 seconds
# For parameter offset_std = 42 ,  Accuracy=67.9% +/- 0.0%  in 13970.9 seconds
# For parameter offset_std = 50 ,  Accuracy=65.2% +/- 0.2%  in 13970.7 seconds
# For parameter offset_std = 60 ,  Accuracy=63.3% +/- 0.4%  in 14118.1 seconds
# 0.7942669942624315 0.8010101902272684
# 0.7785629746176208 0.7890867066865274
# 0.7690240653566248 0.7751600934237015
# 0.7370845555645845 0.7383149389472154
# 0.7081638703772164 0.7192014059164745
# 0.6473928261586028 0.6559936968141109
# 0.6243396201485546 0.6425589100848577
# scanning over noise = [0.5        0.59460356 0.70710678 0.84089642 1.         1.18920712
#  1.41421356 1.68179283 2.        ]
# For parameter noise = 0.500 ,  Accuracy=81.8% +/- 0.1%  in 12238.4 seconds
# For parameter noise = 0.595 ,  Accuracy=80.7% +/- 0.1%  in 12454.6 seconds
# For parameter noise = 0.707 ,  Accuracy=79.2% +/- 0.1%  in 12804.2 seconds
# For parameter noise = 0.841 ,  Accuracy=76.0% +/- 0.2%  in 13244.6 seconds
# For parameter noise = 1.000 ,  Accuracy=72.6% +/- 0.0%  in 11365.4 seconds
# For parameter noise = 1.189 ,  Accuracy=67.6% +/- 0.3%  in 13979.3 seconds
# For parameter noise = 1.414 ,  Accuracy=59.2% +/- 0.0%  in 14308.1 seconds
# For parameter noise = 1.682 ,  Accuracy=49.6% +/- 0.1%  in 14959.9 seconds
# For parameter noise = 2.000 ,  Accuracy=37.7% +/- 0.2%  in 15274.3 seconds
# 0.8165750408575746 0.8199682662227291
# 0.8036244818791672 0.8097554056869507
# 0.7896555735799048 0.794284118131374
# 0.7556285003622404 0.7645904212606776
# 0.6694161793742895 0.68269545173847
# 0.493995858060118 0.4983042244254118
# 0.3728031094252188 0.38140745767326023
# --------------------------------------------------
#  parameter scan : network
# --------------------------------------------------
# scanning over dim1 = [250, 297, 353, 420, 500, 594, 707, 840, 1000]
# For parameter dim1 = 250 ,  Accuracy=73.3% +/- 0.0%  in 7753.2 seconds
# For parameter dim1 = 297 ,  Accuracy=73.0% +/- 0.0%  in 8466.2 seconds
# For parameter dim1 = 353 ,  Accuracy=73.5% +/- 0.0%  in 9315.2 seconds
# For parameter dim1 = 420 ,  Accuracy=74.2% +/- 0.0%  in 10002.9 seconds
# For parameter dim1 = 500 ,  Accuracy=72.6% +/- 0.0%  in 10728.1 seconds
# For parameter dim1 = 594 ,  Accuracy=73.0% +/- 0.0%  in 11829.0 seconds
# For parameter dim1 = 707 ,  Accuracy=72.6% +/- 0.0%  in 13519.3 seconds
# For parameter dim1 = 840 ,  Accuracy=73.3% +/- 0.0%  in 14171.7 seconds
# For parameter dim1 = 1000 ,  Accuracy=72.1% +/- 0.0%  in 16264.4 seconds
# scanning over bn1_bn_momentum = [0.    0.125 0.25  0.375 0.5   0.625 0.75  0.875 1.   ]
# For parameter bn1_bn_momentum = 0.000 ,  Accuracy=72.7% +/- 0.0%  in 12608.5 seconds
# For parameter bn1_bn_momentum = 0.125 ,  Accuracy=72.6% +/- 0.0%  in 10544.2 seconds
# For parameter bn1_bn_momentum = 0.250 ,  Accuracy=72.7% +/- 0.0%  in 10664.3 seconds
# For parameter bn1_bn_momentum = 0.375 ,  Accuracy=72.6% +/- 0.0%  in 10655.7 seconds
# For parameter bn1_bn_momentum = 0.500 ,  Accuracy=72.6% +/- 0.0%  in 10619.0 seconds
# For parameter bn1_bn_momentum = 0.625 ,  Accuracy=72.9% +/- 0.0%  in 10611.0 seconds
# For parameter bn1_bn_momentum = 0.750 ,  Accuracy=73.1% +/- 0.0%  in 10650.7 seconds
# For parameter bn1_bn_momentum = 0.875 ,  Accuracy=73.3% +/- 0.0%  in 10683.8 seconds
# For parameter bn1_bn_momentum = 1.000 ,  Accuracy=16.8% +/- 0.0%  in 10678.3 seconds
# scanning over dim2 = [1000, 1189, 1414, 1681, 2000, 2378, 2828, 3363, 4000]
# For parameter dim2 = 1000 ,  Accuracy=72.5% +/- 0.0%  in 7094.9 seconds
# For parameter dim2 = 1189 ,  Accuracy=71.9% +/- 0.0%  in 8617.6 seconds
# For parameter dim2 = 1414 ,  Accuracy=72.4% +/- 0.0%  in 9437.8 seconds
# For parameter dim2 = 1681 ,  Accuracy=73.3% +/- 0.0%  in 10079.4 seconds
# For parameter dim2 = 2000 ,
# /usr/local/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:603: RuntimeWarning: divide by zero encountered in double_scalars
#   fac = xbar * (1 - xbar) / data.var(ddof=0) - 1
# /usr/local/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:452: RuntimeWarning: invalid value encountered in double_scalars
#   func = [s1 - n * (-psiab + sc.psi(a)),
# /usr/local/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:453: RuntimeWarning: invalid value encountered in double_scalars
#   s2 - n * (-psiab + sc.psi(b))]
# Accuracy=72.6% +/- 0.0%  in 10809.0 seconds
# For parameter dim2 = 2378 ,  Accuracy=73.7% +/- 0.0%  in 12118.0 seconds
# For parameter dim2 = 2828 ,  Accuracy=74.0% +/- 0.0%  in 13491.6 seconds
# For parameter dim2 = 3363 ,  Accuracy=74.5% +/- 0.0%  in 14120.7 seconds
# For parameter dim2 = 4000 ,  Accuracy=73.6% +/- 0.0%  in 15301.6 seconds
# scanning over bn2_bn_momentum = [0.    0.125 0.25  0.375 0.5   0.625 0.75  0.875 1.   ]
# For parameter bn2_bn_momentum = 0.000 ,  Accuracy=74.2% +/- 0.0%  in 8841.3 seconds
# For parameter bn2_bn_momentum = 0.125 ,  Accuracy=72.7% +/- 0.0%  in 10749.9 seconds
# For parameter bn2_bn_momentum = 0.250 ,  Accuracy=72.7% +/- 0.0%  in 10813.6 seconds
# For parameter bn2_bn_momentum = 0.375 ,  Accuracy=72.6% +/- 0.0%  in 10747.3 seconds
# For parameter bn2_bn_momentum = 0.500 ,  Accuracy=72.6% +/- 0.0%  in 10773.9 seconds
# For parameter bn2_bn_momentum = 0.625 ,  Accuracy=72.7% +/- 0.0%  in 10698.6 seconds
# For parameter bn2_bn_momentum = 0.750 ,  Accuracy=72.8% +/- 0.0%  in 10695.7 seconds
# For parameter bn2_bn_momentum = 0.875 ,  Accuracy=72.9% +/- 0.0%  in 10606.8 seconds
# For parameter bn2_bn_momentum = 1.000 ,  Accuracy=69.2% +/- 0.0%  in 10591.7 seconds
# scanning over p_dropout = [0.    0.125 0.25  0.375 0.5   0.625 0.75  0.875 1.   ]
# For parameter p_dropout = 0.000 ,  Accuracy=72.6% +/- 0.0%  in 10519.8 seconds
# For parameter p_dropout = 0.125 ,  Accuracy=72.8% +/- 0.4%  in 11123.2 seconds
# For parameter p_dropout = 0.250 ,  Accuracy=71.8% +/- 0.4%  in 11245.5 seconds
# For parameter p_dropout = 0.375 ,  Accuracy=70.4% +/- 0.4%  in 11237.9 seconds
# For parameter p_dropout = 0.500 ,  Accuracy=68.4% +/- 0.4%  in 11426.5 seconds
# For parameter p_dropout = 0.625 ,  Accuracy=63.9% +/- 0.7%  in 11520.7 seconds
# For parameter p_dropout = 0.750 ,  Accuracy=53.2% +/- 0.8%  in 11670.6 seconds
# For parameter p_dropout = 0.875 ,  Accuracy=33.3% +/- 0.8%  in 11432.5 seconds
# For parameter p_dropout = 1.000 ,  Accuracy=20.5% +/- 0.0%  in 9447.6 seconds
# 0.719181081238982 0.7371675564983522
# 0.7081143291749553 0.7283654160683278
# 0.6942558915629088 0.7139409172003621
# 0.6748306987179887 0.6933894635221003
# 0.6228649355594544 0.654917148193497
# 0.5132871119543289 0.5508631689645253
# 0.3136649764174731 0.352289813440693
#  parameter scan : learning
# --------------------------------------------------
# Using SGD
# --------------------------------------------------
# scanning over lr = [0.0005     0.0005946  0.00070711 0.0008409  0.001      0.00118921
#  0.00141421 0.00168179 0.002     ]
# For parameter lr = 0.001 ,  Accuracy=55.6% +/- 0.0%  in 10381.0 seconds
# For parameter lr = 0.001 ,  Accuracy=55.6% +/- 0.0%  in 10381.0 seconds
# For parameter lr = 0.001 ,  Accuracy=55.6% +/- 0.0%  in 10381.0 seconds
# For parameter lr = 0.001 ,  Accuracy=55.6% +/- 0.0%  in 10381.0 seconds
# For parameter lr = 0.001 ,  Accuracy=55.6% +/- 0.0%  in 10381.0 seconds
# For parameter lr = 0.001 ,  Accuracy=55.6% +/- 0.0%  in 10381.0 seconds
# For parameter lr = 0.001 ,  Accuracy=55.6% +/- 0.0%  in 10381.0 seconds
# For parameter lr = 0.002 ,  Accuracy=74.0% +/- 0.0%  in 10719.2 seconds
# For parameter lr = 0.002 ,  Accuracy=74.0% +/- 0.0%  in 10719.2 seconds
# scanning over momentum = [0.05       0.05946036 0.07071068 0.08408964 0.1        0.11892071
#  0.14142136 0.16817928 0.2       ]
# For parameter momentum = 0.050 ,  Accuracy=72.9% +/- 0.0%  in 10445.0 seconds
# For parameter momentum = 0.059 ,  Accuracy=73.1% +/- 0.0%  in 10564.8 seconds
# For parameter momentum = 0.071 ,  Accuracy=73.5% +/- 0.0%  in 10242.6 seconds
# For parameter momentum = 0.084 ,  Accuracy=73.2% +/- 0.0%  in 10673.0 seconds
# For parameter momentum = 0.100 ,  Accuracy=72.6% +/- 0.0%  in 10597.9 seconds
# For parameter momentum = 0.119 ,  Accuracy=73.0% +/- 0.0%  in 10869.7 seconds
# For parameter momentum = 0.141 ,  Accuracy=74.3% +/- 0.0%  in 10934.2 seconds
# For parameter momentum = 0.168 ,  Accuracy=72.9% +/- 0.0%  in 11095.8 seconds
# For parameter momentum = 0.200 ,  Accuracy=73.1% +/- 0.0%  in 11329.6 seconds
# scanning over minibatch_size = [50, 59, 70, 84, 100, 118, 141, 168, 200]
# For parameter minibatch_size = 50 ,  Accuracy=72.6% +/- 0.0%  in 10556.5 seconds
# For parameter minibatch_size = 59 ,  Accuracy=72.6% +/- 0.0%  in 10467.6 seconds
# For parameter minibatch_size = 70 ,  Accuracy=72.6% +/- 0.0%  in 10431.9 seconds
# For parameter minibatch_size = 84 ,  Accuracy=72.6% +/- 0.0%  in 10435.6 seconds
# For parameter minibatch_size = 100 ,  Accuracy=72.6% +/- 0.0%  in 10494.0 seconds
# For parameter minibatch_size = 118 ,  Accuracy=72.6% +/- 0.0%  in 10490.2 seconds
# For parameter minibatch_size = 141 ,  Accuracy=72.6% +/- 0.0%  in 10506.6 seconds
# For parameter minibatch_size = 168 ,  Accuracy=72.6% +/- 0.0%  in 10509.8 seconds
# For parameter minibatch_size = 200 ,  Accuracy=72.6% +/- 0.0%  in 10513.6 seconds
# scanning over epochs = [12, 14, 17, 21, 25, 29, 35, 42, 50]
# For parameter epochs = 12 ,  Accuracy=53.4% +/- 0.0%  in 4999.3 seconds
# For parameter epochs = 14 ,  Accuracy=64.6% +/- 0.0%  in 5848.2 seconds
# For parameter epochs = 17 ,  Accuracy=70.3% +/- 0.0%  in 7111.1 seconds
# For parameter epochs = 21 ,  Accuracy=72.2% +/- 0.0%  in 8810.2 seconds
# For parameter epochs = 25 ,  Accuracy=72.6% +/- 0.0%  in 10525.3 seconds
# For parameter epochs = 29 ,  Accuracy=73.1% +/- 0.0%  in 12235.1 seconds
# For parameter epochs = 35 ,  Accuracy=73.9% +/- 0.0%  in 14798.1 seconds
# For parameter epochs = 42 ,  Accuracy=74.0% +/- 0.0%  in 17796.8 seconds
# For parameter epochs = 50 ,  Accuracy=74.3% +/- 0.0%  in 21363.8 seconds
# --------------------------------------------------
# Using ADAM
# --------------------------------------------------
# scanning over lr = [0.0005     0.0005946  0.00070711 0.0008409  0.001      0.00118921
#  0.00141421 0.00168179 0.002     ]
# For parameter lr = 0.001 ,  Accuracy=55.6% +/- 0.0%  in 10129.5 seconds
# For parameter lr = 0.001 ,  Accuracy=55.6% +/- 0.0%  in 10129.5 seconds
# For parameter lr = 0.001 ,  Accuracy=55.6% +/- 0.0%  in 10129.5 seconds
# For parameter lr = 0.001 ,  Accuracy=55.6% +/- 0.0%  in 10129.5 seconds
# For parameter lr = 0.001 ,  Accuracy=55.6% +/- 0.0%  in 10129.5 seconds
# For parameter lr = 0.001 ,  Accuracy=55.6% +/- 0.0%  in 10129.5 seconds
# For parameter lr = 0.001 ,  Accuracy=55.6% +/- 0.0%  in 10129.5 seconds
# For parameter lr = 0.002 ,  Accuracy=74.0% +/- 0.0%  in 10528.3 seconds
# For parameter lr = 0.002 ,  Accuracy=74.0% +/- 0.0%  in 10528.3 seconds
# scanning over momentum = [0.05       0.05946036 0.07071068 0.08408964 0.1        0.11892071
#  0.14142136 0.16817928 0.2       ]
# For parameter momentum = 0.050 ,  Accuracy=72.9% +/- 0.0%  in 10283.9 seconds
# For parameter momentum = 0.059 ,  Accuracy=73.1% +/- 0.0%  in 10343.6 seconds
# For parameter momentum = 0.071 ,  Accuracy=73.5% +/- 0.0%  in 10096.4 seconds
# For parameter momentum = 0.084 ,  Accuracy=73.2% +/- 0.0%  in 10558.5 seconds
# For parameter momentum = 0.100 ,  Accuracy=72.6% +/- 0.0%  in 10435.0 seconds
# For parameter momentum = 0.119 ,  Accuracy=73.0% +/- 0.0%  in 10695.2 seconds
# For parameter momentum = 0.141 ,  Accuracy=74.3% +/- 0.0%  in 10836.0 seconds
# For parameter momentum = 0.168 ,  Accuracy=72.9% +/- 0.0%  in 11065.2 seconds
# For parameter momentum = 0.200 ,  Accuracy=73.1% +/- 0.0%  in 11335.8 seconds
# scanning over minibatch_size = [50, 59, 70, 84, 100, 118, 141, 168, 200]
# For parameter minibatch_size = 50 ,  Accuracy=72.6% +/- 0.0%  in 10529.5 seconds
# For parameter minibatch_size = 59 ,  Accuracy=72.6% +/- 0.0%  in 10528.0 seconds
# For parameter minibatch_size = 70 ,  Accuracy=72.6% +/- 0.0%  in 10573.5 seconds
# For parameter minibatch_size = 84 ,  Accuracy=72.6% +/- 0.0%  in 10721.6 seconds
# For parameter minibatch_size = 100 ,  Accuracy=72.6% +/- 0.0%  in 11014.2 seconds
# For parameter minibatch_size = 118 ,  Accuracy=72.6% +/- 0.0%  in 11048.9 seconds
# For parameter minibatch_size = 141 ,  Accuracy=72.6% +/- 0.0%  in 11385.3 seconds
# For parameter minibatch_size = 168 ,  Accuracy=72.6% +/- 0.0%  in 11654.8 seconds
# For parameter minibatch_size = 200 ,  Accuracy=72.6% +/- 0.0%  in 11743.6 seconds
# scanning over epochs = [12, 14, 17, 21, 25, 29, 35, 42, 50]
# For parameter epochs = 12 ,  Accuracy=53.4% +/- 0.0%  in 5358.1 seconds
# For parameter epochs = 14 ,  Accuracy=64.6% +/- 0.0%  in 6330.6 seconds
# For parameter epochs = 17 ,  Accuracy=70.3% +/- 0.0%  in 7847.8 seconds
# For parameter epochs = 21 ,  Accuracy=72.2% +/- 0.0%  in 10107.7 seconds
# For parameter epochs = 25 ,  Accuracy=72.6% +/- 0.0%  in 12767.7 seconds
# For parameter epochs = 29 ,  Accuracy=73.1% +/- 0.0%  in 15306.1 seconds
# For parameter epochs = 35 ,  Accuracy=73.9% +/- 0.0%  in 18283.0 seconds
# For parameter epochs = 42 ,  Accuracy=74.0% +/- 0.0%  in 21826.7 seconds
# For parameter epochs = 50 ,  Accuracy=74.3% +/- 0.0%  in 26400.7 seconds
# --------------------------------------------------
#  parameter scan : retina
# --------------------------------------------------
# scanning over N_theta = [3, 3, 4, 5, 6, 7, 8, 10, 12]
# For parameter N_theta = 3 ,   currently locked with  ../data/_tmp_scanning/N_theta__3.npy_lock
# For parameter N_theta = 3 ,   currently locked with  ../data/_tmp_scanning/N_theta__3.npy_lock
# For parameter N_theta = 4 ,  Accuracy=72.7% +/- 0.2%  in 13117.0 seconds
# For parameter N_theta = 5 ,   currently locked with  ../data/_tmp_scanning/N_theta__5.npy_lock
# For parameter N_theta = 6 ,  Accuracy=72.6% +/- 0.0%  in 13345.6 seconds
# For parameter N_theta = 7 ,  Accuracy=73.0% +/- 0.3%  in 16459.2 seconds
# For parameter N_theta = 8 ,  Accuracy=73.0% +/- 0.0%  in 17804.6 seconds
# For parameter N_theta = 10 ,  Accuracy=72.7% +/- 0.2%  in 20169.3 seconds
# For parameter N_theta = 12 ,  Accuracy=72.3% +/- 0.1%  in 22134.3 seconds
# 0.7217117753639047 0.7319060415978398
# 0.7234496048275494 0.7357027697778749
# 0.7290839792586069 0.7303155408874129
# 0.7219806078322497 0.7324851254064852
# 0.720389606019174 0.7247047826639834
# scanning over N_azimuth = [13, 15, 18, 21, 26, 30, 36, 43, 52]
# For parameter N_azimuth = 13 ,  Accuracy=67.3% +/- 0.2%  in 8797.0 seconds
# For parameter N_azimuth = 15 ,  Accuracy=68.9% +/- 0.3%  in 9233.1 seconds
# For parameter N_azimuth = 18 ,  Accuracy=71.0% +/- 0.3%  in 11960.4 seconds
# For parameter N_azimuth = 21 ,  Accuracy=72.6% +/- 0.3%  in 12958.9 seconds
# For parameter N_azimuth = 26 ,  Accuracy=72.6% +/- 0.0%  in 12807.6 seconds
# For parameter N_azimuth = 30 ,  Accuracy=72.3% +/- 0.2%  in 15880.0 seconds
# For parameter N_azimuth = 36 ,  Accuracy=65.5% +/- 0.5%  in 17773.2 seconds
# For parameter N_azimuth = 43 ,  Accuracy=23.5% +/- 1.0%  in 20494.2 seconds
# For parameter N_azimuth = 52 ,  Accuracy=15.0% +/- 0.0%  in 21847.6 seconds
# 0.6698869394029471 0.676952339174677
# 0.6829429159975896 0.6959167625251539
# 0.7030102467190686 0.717233830412021
# 0.718284603497664 0.733889856060377
# 0.7192888247623562 0.7266946100417341
# 0.6435507673606702 0.6659054907088187
# 0.21383611707985475 0.25784517545923136
# 0.14950545950154098 0.15104630706676625
# scanning over N_eccentricity = [5, 5, 7, 8, 10, 11, 14, 16, 20]
# For parameter N_eccentricity = 5 ,  Accuracy=57.8% +/- 0.1%  in 9868.5 seconds
# For parameter N_eccentricity = 5 ,  Accuracy=57.8% +/- 0.1%  in 9868.5 seconds
# For parameter N_eccentricity = 7 ,  Accuracy=68.0% +/- 0.0%  in 12623.8 seconds
# For parameter N_eccentricity = 8 ,  Accuracy=71.9% +/- 0.1%  in 13567.7 seconds
# For parameter N_eccentricity = 10 ,  Accuracy=72.6% +/- 0.0%  in 13053.8 seconds
# For parameter N_eccentricity = 11 ,  Accuracy=46.8% +/- 0.7%  in 15805.1 seconds
# For parameter N_eccentricity = 14 ,  Accuracy=13.2% +/- 0.1%  in 17666.4 seconds
# For parameter N_eccentricity = 16 ,  Accuracy=12.8% +/- 0.0%  in 18266.2 seconds
# For parameter N_eccentricity = 20 ,  Accuracy=11.6% +/- 0.1%  in 19177.8 seconds
# 0.5761939918853892 0.5805043909033524
# 0.6794259150162775 0.6812733163120732
# 0.7175786710904343 0.7209679419395
# 0.4516130896555476 0.4839717106163929
# 0.1303748126855143 0.13283047172387608
# 0.12728437121768693 0.12851700588769677
# 0.11434230129333021 0.11832378652996611
# scanning over rho = [0.705      0.83839102 0.99702056 1.18566395 1.41       1.67678203
#  1.99404112 2.37132789 2.82      ]
# For parameter rho = 0.705 ,   currently locked with  ../data/_tmp_scanning/rho__0_705.npy_lock
# For parameter rho = 0.838 ,   currently locked with  ../data/_tmp_scanning/rho__0_838.npy_lock
# For parameter rho = 0.997 ,   currently locked with  ../data/_tmp_scanning/rho__0_997.npy_lock
# For parameter rho = 1.186 ,  Accuracy=65.8% +/- 0.1%  in 17452.0 seconds
# For parameter rho = 1.410 ,  Accuracy=72.6% +/- 0.0%  in 12679.7 seconds
# For parameter rho = 1.677 ,  Accuracy=13.8% +/- 0.0%  in 13352.4 seconds
# For parameter rho = 1.994 ,  Accuracy=13.0% +/- 0.2%  in 13542.0 seconds
# For parameter rho = 2.371 ,  Accuracy=13.0% +/- 0.2%  in 13574.4 seconds
# For parameter rho = 2.820 ,  Accuracy=13.3% +/- 0.2%  in 13608.9 seconds
# 0.6565902809451738 0.6593582561317978
# 0.13804222247227396 0.13865809018396635
# 0.12538488820766075 0.13408246486233577
# 0.12648145515318995 0.13361370977029496
# 0.12908156133436832 0.1362125224446702

# %%
print(accuracies)
# Out:
# {1.1856639455077373: array([6.56400000e-01, 6.58200000e-01, 6.58200000e-01, 6.58200000e-01,
#        6.58200000e-01, 6.58200000e-01, 6.58200000e-01, 6.58200000e-01,
#        1.74520218e+04]), 1.41: array([7.26200000e-01, 7.26200000e-01, 7.26200000e-01, 7.26200000e-01,
#        7.26200000e-01, 7.26200000e-01, 7.26200000e-01, 7.26200000e-01,
#        1.26797069e+04]), 1.6767820321538365: array([1.38000000e-01, 1.38400000e-01, 1.38400000e-01, 1.38400000e-01,
#        1.38400000e-01, 1.38400000e-01, 1.38400000e-01, 1.38400000e-01,
#        1.33523757e+04]), 1.994041122946064: array([1.24800000e-01, 1.30400000e-01, 1.30400000e-01, 1.30400000e-01,
#        1.30400000e-01, 1.30400000e-01, 1.30400000e-01, 1.30400000e-01,
#        1.35419781e+04]), 2.3713278910154747: array([1.26000000e-01, 1.30600000e-01, 1.30600000e-01, 1.30600000e-01,
#        1.30600000e-01, 1.30600000e-01, 1.30600000e-01, 1.30600000e-01,
#        1.35743797e+04]), 2.82: array([1.28600000e-01, 1.33200000e-01, 1.33200000e-01, 1.33200000e-01,
#        1.33200000e-01, 1.33200000e-01, 1.33200000e-01, 1.33200000e-01,
#        1.36088819e+04])}

# %%
print(accuracies[list(accuracies.keys())[0]])
# Out:
# [6.56400000e-01 6.58200000e-01 6.58200000e-01 6.58200000e-01
#  6.58200000e-01 6.58200000e-01 6.58200000e-01 6.58200000e-01
#  1.74520218e+04]

# %%
data = accuracies[list(accuracies.keys())[0]][:-1]
print(data)
# Out:
# [0.6564 0.6582 0.6582 0.6582 0.6582 0.6582 0.6582 0.6582]

# %%
from scipy.stats import beta
beta.fit(data)
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:515: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# /usr/local/lib/python3.7/site-packages/scipy/optimize/minpack.py:162: RuntimeWarning: The number of calls to function has reached maxfev = 600.
#   warnings.warn(msg, RuntimeWarning)
# (2.716218311859877e-10,
#  4.0743260411275294e-11,
#  0.6563999999998591,
#  0.0018000000001408003)

# %%
a1, b1, loc1, scale1 = beta.fit(data, floc=0, fscale=1)
print(a1, b1, loc1, scale1)
# Out:
# 418369.50952543947 217474.57265896935 0 1

# %% [markdown]
# From https://github.com/laurentperrinet/bayesianchangepoint/blob/master/bayesianchangepoint/bcp.py#L312

# %%
p_low, p_sup = beta.ppf([.05, .95], a=a1, b=b1)
p_low, p_sup
# Out:
# (0.6569961618105908, 0.6589532717859645)

# %%
from scipy.stats import beta
beta.fit(data)
a1, b1, loc1, scale1 = beta.fit(data, floc=0, fscale=1)
p_low, p_sup = beta.ppf([.05, .95], a=a1, b=b1)
p_low, p_sup
# Out:
# (0.6569961618105908, 0.6589532717859645)

# %%
results['sf_0']['value'],  results['sf_0']['accuracy']
# Out:
# ([0.1,
#   0.11892071150027211,
#   0.14142135623730953,
#   0.16817928305074292,
#   0.2,
#   0.23784142300054423,
#   0.28284271247461906,
#   0.33635856610148585,
#   0.4],
#  [66.62750000000001,
#   67.2825,
#   68.67750000000001,
#   71.18749999999999,
#   72.61999999999999,
#   74.1175,
#   75.1625,
#   76.08250000000001,
#   76.5725])

# %% [markdown]
# ## parameter scan

# %%
for parameter in results.keys():
    print('--->',  parameter)
    fig, ax = plt.subplots(figsize=(8, 3))
    ax.plot(results[parameter]['value'], 
            results[parameter]['accuracy'], 'r.')
    plt.xlabel('Variable ' +  parameter)
    plt.ylabel('Accuracy (%)')

    plt.show()
# Out:
# ---> sf_0
# ---> B_sf
# ---> offset_std
# ---> noise
# ---> dim1
# ---> bn1_bn_momentum
# ---> dim2
# ---> bn2_bn_momentum
# ---> p_dropout
# ---> lr
# ---> momentum
# ---> minibatch_size
# ---> epochs
# ---> N_theta
# ---> N_azimuth
# ---> N_eccentricity
# ---> rho

# %%
results['sf_0']
# Out:
# {'value': [0.1,
#   0.11892071150027211,
#   0.14142135623730953,
#   0.16817928305074292,
#   0.2,
#   0.23784142300054423,
#   0.28284271247461906,
#   0.33635856610148585,
#   0.4],
#  'accuracy': [66.62750000000001,
#   67.2825,
#   68.67750000000001,
#   71.18749999999999,
#   72.61999999999999,
#   74.1175,
#   75.1625,
#   76.08250000000001,
#   76.5725],
#  'p_low': [65.9354347953428,
#   67.05173371444766,
#   68.66211153798774,
#   70.26937037266737,
#   72.61999999999999,
#   74.10211297131013,
#   75.0548051343286,
#   75.60583105877005,
#   75.66588732190476],
#  'p_sup': [67.31567593241883,
#   67.51281206002236,
#   68.69288622706955,
#   72.09630387480117,
#   72.61999999999999,
#   74.13288379372855,
#   75.27002513100507,
#   76.5556478736889,
#   77.46601825405057]}

# %%
def plot_accuracy(result, xmin=10, fig=None, ax=None, ylabel=None):
    if fig is None: fig, ax = plt.subplots(figsize=(5, 5))
    print(result['p_low'], result['p_sup'])
    #ax.plot(result['accuracy'], result['value'], "o", color='blue')
    # print(value, accuracy)
    ax.hlines(y=result['value'], xmin=result['accuracy'], xmax=100, color='red')
    ax.hlines(y=result['value'], xmin=xmin, xmax=result['accuracy'], color='skyblue')
    ax.hlines(y=result['value'], xmin=result['p_low'], xmax=result['p_sup'], color='blue', alpha=1., lw=7)

    if ylabel=None:
        ylabel = parameter.capitalize()
    plt.ylabel(ylabel)
    #print( results[parameter]['value'] )
    #print( np.min([np.float(k) for k in results[parameter]['value']]))
    #ax.vlines(100, np.min(results[parameter]['value']), np.max(results[parameter]['value']), 'k', label='max')
    plt.xlabel('Accuracy (%)')
    # Only draw spine between the y-ticks
    #ax.spines['left'].set_bounds(-1, 1)
    # Hide the right and top spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    # Only show ticks on the left and bottom spines
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')

    return fig, ax

# %%
figname_ = 'accuracy_'
figname_ = ''

tex = ''
for parameter in results.keys():
    print('--->',  parameter)
    fig, ax = plot_accuracy(results[parameter])
    plt.show()
    if not figname_ == '':
        fig_dir = './'
        fig_ext = '.pdf'
        fname = figname_ + parameter + fig_ext
        tex += "\includegraphics[width=.0666\linewidth]{"+ fname + "} \n"
        fig.savefig(os.path.join(fig_dir, fname),
                bbox_inches='tight', pad_inches=0)
print(tex)
# Out:
# ---> sf_0
# [65.9354347953428, 67.05173371444766, 68.66211153798774, 70.26937037266737, 72.61999999999999, 74.10211297131013, 75.0548051343286, 75.60583105877005, 75.66588732190476] [67.31567593241883, 67.51281206002236, 68.69288622706955, 72.09630387480117, 72.61999999999999, 74.13288379372855, 75.27002513100507, 76.5556478736889, 77.46601825405057]
# ---> B_sf
# [72.87268643900804, 73.45087921176268, 72.16099482677696, 73.36751558862322, 72.54255994834811, 71.03680908354787, 70.98899486471537, 69.13720887135891, 69.50689336641372] [73.05720580106596, 74.18730126403184, 74.42746917518677, 73.76695843935568, 72.72733444713734, 71.90105842959593, 71.72945094443371, 71.08791456417984, 71.61606564889054]
# ---> offset_std
# [79.42669942624315, 77.85629746176208, 76.90240653566248, 73.70845555645845, 72.61999999999999, 70.81638703772164, 67.86, 64.73928261586028, 62.43396201485546] [80.10101902272683, 78.90867066865273, 77.51600934237015, 73.83149389472155, 72.61999999999999, 71.92014059164745, 67.86, 65.59936968141109, 64.25589100848576]
# ---> noise
# [81.65750408575747, 80.36244818791673, 78.96555735799048, 75.56285003622403, 72.61999999999999, 66.94161793742896, 59.2325, 49.3995858060118, 37.28031094252188] [81.9968266222729, 80.97554056869507, 79.4284118131374, 76.45904212606776, 72.61999999999999, 68.269545173847, 59.2325, 49.83042244254118, 38.140745767326024]
# ---> dim1
# [73.32, 72.96, 73.49999999999999, 74.19999999999999, 72.61999999999999, 72.96000000000002, 72.60000000000001, 73.32000000000001, 72.12] [73.32, 72.96, 73.49999999999999, 74.19999999999999, 72.61999999999999, 72.96000000000002, 72.60000000000001, 73.32000000000001, 72.12]
# ---> bn1_bn_momentum
# [72.66, 72.61999999999999, 72.74, 72.61999999999999, 72.61999999999999, 72.85999999999999, 73.05999999999999, 73.25999999999999, 16.78] [72.66, 72.61999999999999, 72.74, 72.61999999999999, 72.61999999999999, 72.85999999999999, 73.05999999999999, 73.25999999999999, 16.78]
# ---> dim2
# [72.47999999999999, 71.91999999999999, 72.38000000000001, 73.25999999999999, 72.61999999999999, 73.74000000000001, 74.02, 74.52, 73.62] [72.47999999999999, 71.91999999999999, 72.38000000000001, 73.25999999999999, 72.61999999999999, 73.74000000000001, 74.02, 74.52, 73.62]
# ---> bn2_bn_momentum
# [74.24, 72.67999999999999, 72.69999999999999, 72.62, 72.6, 72.7, 72.82000000000001, 72.88000000000001, 69.18] [74.24, 72.67999999999999, 72.69999999999999, 72.62, 72.6, 72.7, 72.82000000000001, 72.88000000000001, 69.18]
# ---> p_dropout
# [72.61999999999999, 71.9181081238982, 70.81143291749554, 69.42558915629088, 67.48306987179888, 62.28649355594544, 51.32871119543289, 31.36649764174731, 20.54] [72.61999999999999, 73.71675564983522, 72.83654160683278, 71.39409172003622, 69.33894635221003, 65.4917148193497, 55.08631689645252, 35.2289813440693, 20.54]
# ---> lr
# [55.60000000000001, 55.60000000000001, 55.60000000000001, 55.60000000000001, 55.60000000000001, 55.60000000000001, 55.60000000000001, 74.04, 74.04] [55.60000000000001, 55.60000000000001, 55.60000000000001, 55.60000000000001, 55.60000000000001, 55.60000000000001, 55.60000000000001, 74.04, 74.04]
# ---> momentum
# [72.9, 73.14, 73.52, 73.24, 72.61999999999999, 73.00000000000001, 74.28, 72.92, 73.06] [72.9, 73.14, 73.52, 73.24, 72.61999999999999, 73.00000000000001, 74.28, 72.92, 73.06]
# ---> minibatch_size
# [72.61999999999999, 72.61999999999999, 72.61999999999999, 72.61999999999999, 72.61999999999999, 72.61999999999999, 72.61999999999999, 72.61999999999999, 72.61999999999999] [72.61999999999999, 72.61999999999999, 72.61999999999999, 72.61999999999999, 72.61999999999999, 72.61999999999999, 72.61999999999999, 72.61999999999999, 72.61999999999999]
# ---> epochs
# [53.42, 64.6, 70.25999999999999, 72.22, 72.61999999999999, 73.10000000000001, 73.94, 73.97999999999999, 74.26] [53.42, 64.6, 70.25999999999999, 72.22, 72.61999999999999, 73.10000000000001, 73.94, 73.97999999999999, 74.26]
# ---> N_theta
# [72.17117753639047, 72.61999999999999, 72.34496048275494, 72.9083979258607, 72.19806078322497, 72.0389606019174] [73.19060415978397, 72.61999999999999, 73.57027697778749, 73.03155408874129, 73.24851254064852, 72.47047826639835]
# ---> N_azimuth
# [66.98869394029471, 68.29429159975896, 70.30102467190686, 71.8284603497664, 72.61999999999999, 71.92888247623563, 64.35507673606702, 21.383611707985477, 14.950545950154098] [67.6952339174677, 69.59167625251538, 71.7233830412021, 73.3889856060377, 72.61999999999999, 72.66946100417341, 66.59054907088186, 25.784517545923137, 15.104630706676625]
# ---> N_eccentricity
# [57.61939918853892, 67.94259150162775, 71.75786710904343, 72.61999999999999, 45.16130896555476, 13.03748126855143, 12.728437121768692, 11.434230129333022] [58.05043909033524, 68.12733163120733, 72.09679419395, 72.61999999999999, 48.39717106163929, 13.283047172387608, 12.851700588769678, 11.832378652996612]
# ---> rho
# [65.65902809451738, 72.61999999999999, 13.804222247227397, 12.538488820766075, 12.648145515318996, 12.908156133436833] [65.93582561317977, 72.61999999999999, 13.865809018396636, 13.408246486233576, 13.361370977029496, 13.62125224446702]

# %% [markdown]
# # summary

# %% [raw]
# %ls ../data/_tmp_scanning

# %%
parameters = ['dim1', 'dim2', ' N_azimuth', 'epochs'] # 'noise', 'lr', 
fig, axs = plt.subplots(1, len(parameters), figsize = (figwidth, figwidth/len(parameters)*1.1))

for ax, parameter in zip(axs, parameters):
    fig, ax = plot_accuracy(results[parameter], xmin=10, fig=fig, ax=ax)

fig.savefig(figname + '.pdf', bbox_inches='tight', pad_inches=0.15)
# Out:
# [73.32, 72.96, 73.49999999999999, 74.19999999999999, 72.61999999999999, 72.96000000000002, 72.60000000000001, 73.32000000000001, 72.12] [73.32, 72.96, 73.49999999999999, 74.19999999999999, 72.61999999999999, 72.96000000000002, 72.60000000000001, 73.32000000000001, 72.12]
# [72.47999999999999, 71.91999999999999, 72.38000000000001, 73.25999999999999, 72.61999999999999, 73.74000000000001, 74.02, 74.52, 73.62] [72.47999999999999, 71.91999999999999, 72.38000000000001, 73.25999999999999, 72.61999999999999, 73.74000000000001, 74.02, 74.52, 73.62]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-adfd5fcccbf9> in <module>
#       3
#       4 for ax, parameter in zip(axs, parameters):
# ----> 5     fig, ax = plot_accuracy(results[parameter], xmin=10, fig=fig, ax=ax)
#       6
#       7 fig.savefig(figname + '.pdf', bbox_inches='tight', pad_inches=0.15)
#
# KeyError: ' N_azimuth'

# %%
figname + '.pdf'
# Out:
# '../figures/fig_params.pdf'

# %% [markdown]
# # post-processing

# %%
# !convert  -density {dpi_export} {figname}.pdf {figname}.jpg
# !convert  -density {dpi_export} {figname}.pdf {figname}.png
#!convert  -density {dpi_export} -resize 5400  -units pixelsperinch -flatten  -compress lzw  -depth 8 {fname}.pdf {fname}.tiff

# %%
from IPython.display import Image
Image('{figname}.png'.format(figname=figname))

# %%
# !ls  -l {figname}*
# Out:
# -rw-r--r--  1 laurentperrinet  staff  721914 Mar 28 11:52 ../figures/fig_params.jpg
# -rw-r--r--  1 laurentperrinet  staff   13601 Mar 28 11:52 ../figures/fig_params.pdf
# -rw-r--r--  1 laurentperrinet  staff   78038 Mar 28 11:52 ../figures/fig_params.png
