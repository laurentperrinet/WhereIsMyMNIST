# %% [markdown]
# This notebook introduces the problem addressed in this paper:
#
#  - localizating an object in a large image
#  - foveation
#  - action (saccade)

# %%
figname = '../figures/fig_result'

# %%
# %run 0_parameters.ipynb
# Out:
# This notebook introduces the problem addressed in this paper:
#
#  - localizating an object in a large image
#  - foveation
#  - action (saccade)
#
#
# Using filename= ../data/2019-03-19
# {'w': 28, 'minibatch_size': 100, 'train_batch_size': 50000, 'test_batch_size': 5000, 'noise_batch_size': 1000, 'mean': 0.1307, 'std': 0.3081, 'N_pic': 128, 'offset_std': 30, 'offset_max': 35, 'noise': 0.7, 'contrast': 0.8, 'sf_0': 0.2, 'B_sf': 0.3, 'N_theta': 6, 'N_azimuth': 16, 'N_eccentricity': 10, 'N_phase': 2, 'rho': 1.41, 'bias_deconv': True, 'p_dropout': 0.5, 'dim1': 1000, 'dim2': 1000, 'lr': 0.0001, 'do_adam': True, 'bn1_bn_momentum': 0.0, 'bn2_bn_momentum': 0.0, 'momentum': 0.1, 'epochs': 50, 'default_param_file': '../data/default_param.py', 'num_processes': 1, 'no_cuda': True, 'log_interval': 100, 'verbose': 1, 'filename': '../data/2019-03-19', 'seed': 2019, 'N_cv': 2}
# Overwriting train.py
# -rw-r--r--  1 laurentperrinet  wheel   397M Mar 19 15:38 /tmp/dataset_train__0.2_0.3_0.7_0.8_30_35_6_16_10_2_1.41_128_50000.pt
# -rw-r--r--  1 laurentperrinet  wheel   352M Mar 19 15:39 /tmp/dataset_test__0.2_0.3_0.7_0.8_30_35_6_16_10_2_1.41_128_5000.pt
# total 280
# -rw-r--r--  1 laurentperrinet  staff   216B Mar 18 14:28 sf_0__0_141.npy
# -rw-r--r--  1 laurentperrinet  staff   216B Mar 18 14:29 sf_0__0_100.npy
# -rw-r--r--  1 laurentperrinet  staff   216B Mar 18 14:29 sf_0__0_119.npy
# -rw-r--r--  1 laurentperrinet  staff   216B Mar 18 14:30 sf_0__0_238.npy
# -rw-r--r--  1 laurentperrinet  staff   216B Mar 18 14:31 sf_0__0_283.npy
# -rw-r--r--  1 laurentperrinet  staff   216B Mar 18 14:32 sf_0__0_168.npy
# -rw-r--r--  1 laurentperrinet  staff   216B Mar 18 14:33 sf_0__0_200.npy
# -rw-r--r--  1 laurentperrinet  staff   216B Mar 18 14:36 bias_deconv__False.npy
# -rw-r--r--  1 laurentperrinet  staff   216B Mar 18 14:39 bias_deconv__True.npy
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 00:24 sf_0__0_336.npy
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 01:35 sf_0__0_400.npy
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 01:36 B_sf__0_150.npy
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 06:27 B_sf__0_178.npy
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 06:27 offset_std__15.npy_lock
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 06:30 B_sf__0_212.npy
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 06:30 offset_std__17.npy_lock
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 06:30 B_sf__0_252.npy
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 06:30 offset_std__21.npy_lock
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 06:30 B_sf__0_300.npy
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 06:30 offset_std__25.npy_lock
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 06:31 B_sf__0_357.npy
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 06:31 offset_std__30.npy_lock
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 12:32 B_sf__0_424.npy
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 12:32 offset_std__35.npy_lock
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 13:42 B_sf__0_505.npy
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 13:42 offset_std__42.npy_lock
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 13:44 B_sf__0_600.npy
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 13:44 offset_std__50.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 offset_std__60.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 noise__0_350.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 noise__0_416.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 noise__0_495.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 noise__0_589.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 noise__0_700.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 noise__0_832.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 noise__0_990.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 noise__1_177.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 noise__1_400.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 contrast__0_400.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 contrast__0_476.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 contrast__0_566.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 contrast__0_673.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 contrast__0_800.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 contrast__0_951.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 contrast__1_131.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 contrast__1_345.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:33 contrast__1_600.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 sf_0__0_025.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 sf_0__0_042.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 sf_0__0_071.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 sf_0__0_566.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 sf_0__0_951.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 sf_0__1_600.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 B_sf__0_037.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 B_sf__0_063.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 B_sf__0_106.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 B_sf__0_849.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 B_sf__1_427.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 B_sf__2_400.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 offset_std__3.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 offset_std__6.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 offset_std__10.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 offset_std__84.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 offset_std__142.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 offset_std__240.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 noise__0_087.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 noise__0_147.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 noise__0_247.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 noise__1_980.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 noise__3_330.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 noise__5_600.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 contrast__0_100.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 contrast__0_168.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 contrast__0_283.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 contrast__2_263.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 contrast__3_805.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 14:34 contrast__6_400.npy_lock
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 14:44 dim1__500.npy
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 14:46 bn1_bn_momentum__0_000.npy
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 14:48 bn1_bn_momentum__0_125.npy
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 14:49 bn1_bn_momentum__0_250.npy
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 14:49 bn1_bn_momentum__0_375.npy
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 14:49 bn1_bn_momentum__0_625.npy
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 14:49 bn1_bn_momentum__0_500.npy
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 14:52 dim1__594.npy
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 15:00 bn1_bn_momentum__0_750.npy
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:00 dim2__840.npy_lock
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 15:00 dim2__500.npy
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:00 dim2__1000.npy_lock
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 15:01 dim2__594.npy
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:01 dim2__1189.npy_lock
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 15:02 dim2__707.npy
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:02 dim2__1414.npy_lock
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 15:04 bn1_bn_momentum__0_875.npy
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:04 dim2__1681.npy_lock
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 15:04 bn1_bn_momentum__1_000.npy
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:04 dim2__2000.npy_lock
# -rw-r--r--  1 laurentperrinet  staff   152B Mar 19 15:05 dim1__707.npy
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:05 dim1__840.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:31 dim1__1000.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:31 dim1__1189.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:49 dim1__1414.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:49 dim1__1681.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:49 dim1__2000.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:49 bn2_bn_momentum__0_000.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:49 bn2_bn_momentum__0_125.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:49 bn2_bn_momentum__0_250.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:50 bn2_bn_momentum__0_375.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:50 bn2_bn_momentum__0_500.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:50 bn2_bn_momentum__0_625.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:50 bn2_bn_momentum__0_750.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:50 bn2_bn_momentum__0_875.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:50 bn2_bn_momentum__1_000.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:50 p_dropout__0_000.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:50 p_dropout__0_125.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:50 p_dropout__0_250.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 p_dropout__0_375.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 p_dropout__0_500.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 p_dropout__0_625.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 p_dropout__0_750.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 p_dropout__0_875.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 p_dropout__1_000.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 lr__0_000.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 momentum__0_050.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 momentum__0_059.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 momentum__0_071.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 momentum__0_084.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 momentum__0_100.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 momentum__0_119.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 momentum__0_141.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 momentum__0_168.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 momentum__0_200.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 minibatch_size__50.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 minibatch_size__59.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 minibatch_size__70.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 minibatch_size__84.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 minibatch_size__100.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 minibatch_size__118.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 minibatch_size__141.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 minibatch_size__168.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:51 minibatch_size__200.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 epochs__25.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 epochs__29.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 epochs__35.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 epochs__42.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 epochs__50.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 epochs__59.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 epochs__70.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 epochs__84.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 epochs__100.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 lr_adam_0_000.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 momentum_adam_0_050.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 momentum_adam_0_059.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 momentum_adam_0_071.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 momentum_adam_0_084.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 momentum_adam_0_100.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 momentum_adam_0_119.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 momentum_adam_0_141.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 momentum_adam_0_168.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 momentum_adam_0_200.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 minibatch_size_adam_50.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 minibatch_size_adam_59.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 minibatch_size_adam_70.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 minibatch_size_adam_84.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:52 minibatch_size_adam_100.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 minibatch_size_adam_118.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 minibatch_size_adam_141.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 minibatch_size_adam_168.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 minibatch_size_adam_200.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 epochs_adam_25.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 epochs_adam_29.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 epochs_adam_35.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 epochs_adam_42.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 epochs_adam_50.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 epochs_adam_59.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 epochs_adam_70.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 epochs_adam_84.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 epochs_adam_100.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 lr__0_001.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 momentum__0_013.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 momentum__0_021.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 momentum__0_035.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 momentum__0_283.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 momentum__0_476.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 momentum__0_800.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 minibatch_size__12.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 minibatch_size__21.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 minibatch_size__35.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 minibatch_size__282.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 minibatch_size__475.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:53 minibatch_size__800.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:54 epochs__6.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:54 epochs__10.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:54 epochs__17.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:54 epochs__141.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:54 epochs__237.npy_lock
# -rw-r--r--  1 laurentperrinet  staff     0B Mar 19 15:54 epochs__400.npy_lock
# 2019-03-19T16:14:32+01:00
#
# CPython 3.7.2
# IPython 7.3.0
#
# numpy 1.16.2
# matplotlib 3.0.3
# torch 1.0.1.post2
#
# compiler   : Clang 10.0.0 (clang-1000.11.45.5)
# system     : Darwin
# release    : 18.2.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 36
# interpreter: 64bit
# host name  : fortytwo
# Git hash   : 1325efca6fd377788e72b4687573ec2ee7b68844
# Git repo   : https://github.com/laurentperrinet/WhereIsMyMNIST
# Git branch : master

# %% [markdown]
# # Training the Where network

# %%
# %ls /tmp/*pt
# Out:
# /tmp/dataset_test__0.2_0.3_0.7_0.8_30_35_6_16_10_2_1.41_128_5000.pt
# /tmp/dataset_train__0.2_0.3_0.7_0.8_30_35_6_16_10_2_1.41_128_50000.pt

# %% [raw]
# %rm /tmp/*pt

# %%
# %ls -lh ../data/*pt
# Out:
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 13 22:14 ../data/2019-03-13_train.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 14 17:44 ../data/2019-03-14_b_train.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 14 06:17 ../data/2019-03-14_train.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 14 14:54 ../data/2019-03-14_train3.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 14 19:28 ../data/2019-03-14_train4.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 15 22:18 ../data/2019-03-15_train.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 15 15:31 ../data/2019-03-15_train_b.pt
# -rw-r--r--@ 1 laurentperrinet  staff    12M Mar 19 00:19 ../data/2019-03-18_train.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 19 15:18 ../data/2019-03-19_bis_train.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 19 15:54 ../data/2019-03-19_train.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Mar 14 12:31 ../data/MNIST_cnn.pt

# %%
from main import init
#args = init(filename='debug')
args = init(filename='../data/2019-03-19_bis')

from where import Where
from what import WhatNet
where = Where(args)

filename_train = args.filename + '_train.pt'
#filename_train = "../data/2019-03-14_train4.pt"
#filename_train = "../data/2019-03-15_train_b.pt"
# %ls -lh {filename_train}
#%rm {filename_train}
#%rm  ../data/debug_train.pt

where.train(filename_train)
# Out:
# Loading accuracy... min, max= 0.0145 0.9852
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 19 15:18 ../data/2019-03-19_bis_train.pt
# Loading file ../data/2019-03-19_bis_train.pt

# %% [markdown]
# # Visualisation of some examples

# %%
data, label = next(iter(where.display.loader_test))
idx_start, idx_stop = 0, 11

positions, data_fullfield, retina_data, accuracy_colliculus = where.minibatch(data)

# %% [markdown]
# ## knowing the target position

# %%
im = np.zeros((args.test_batch_size, args.w, args.w))
for idx in range(args.test_batch_size):
    im[idx, :, :] = where.extract(data_fullfield[idx, :, :], positions[idx]['i_offset'], positions[idx]['j_offset'])
proba = where.classify_what(im).numpy()
pred = proba.argmax(axis=1) # get the index of the max log-probability
#acc = proba[:, pred]
acc_max = (pred==label.numpy()).mean()
print('Accuracy max (knowing the position)=', acc_max)
# Out:
# Accuracy max (knowing the position)= 0.9642

# %%
for idx in range(idx_start, idx_stop):
    fig = plt.figure(figsize = (15, 8))
    
    ax = fig.add_subplot(141)
    ax = where.display.show(ax, data_fullfield[idx, :, :])
    ax.set_title(f"i={positions[idx]['i_offset']}, j={positions[idx]['j_offset']}")
    
    ax = fig.add_subplot(142)
    data_retina = where.retina.retina(data_fullfield[idx, :, :])
    ax = where.retina.show(ax, where.retina.retina_invert(data_retina))
    ax.set_title(f"idx={idx}")
              
    ax = fig.add_subplot(143, projection='polar')
    ax.pcolor(where.retina.theta, where.retina.log_r, accuracy_colliculus[idx, :].numpy().reshape((args.N_azimuth, args.N_eccentricity)), cmap=plt.plasma())
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_title("True")

    ax = fig.add_subplot(144)
    ax = where.display.show(ax, im[idx, :, :], do_cross=False)
    result = '' if pred[idx]==label[idx].numpy() else 'FALSE'
    ax.set_title(f"pred={pred[idx]} acc={proba[idx,pred[idx]]:.2f} {result}")

# %% [markdown]
# ## predicting the position of the target

# %%
pred_accuracy_colliculus = where.pred_accuracy(retina_data)
print('pred_accuracy_colliculus.shape=', pred_accuracy_colliculus.shape)
# Out:
# pred_accuracy_colliculus.shape= (5000, 160)

# %%
for idx in range(idx_start, idx_stop):
    fig = plt.figure(figsize = (15, 8))

    ax = fig.add_subplot(131, projection='polar')
    ax.pcolor(where.retina.theta, where.retina.log_r, pred_accuracy_colliculus[idx, :].reshape((args.N_azimuth, args.N_eccentricity)), cmap=plt.plasma())
    ax.set_title("Predicted")
    ax.set_yticklabels([])
    ax.set_xticklabels([])
              
    x = where.retina.accuracy_invert(pred_accuracy_colliculus[idx, :])
    ax = fig.add_subplot(132)
    ax.imshow(x, vmin=0, cmap=plt.plasma())
    ax.set_title("Pred visual space")
    
    i_pred, j_pred = where.index_prediction(pred_accuracy_colliculus[idx, :])
    
    ax = fig.add_subplot(133)
    ax = where.display.show(ax, data_fullfield[idx, :, :])
    ax.set_title(f"i={positions[idx]['i_offset']}/{i_pred}, j={positions[idx]['j_offset']}/{j_pred}")
    ax.plot([positions[idx]['j_offset']+args.N_pic//2], [positions[idx]['i_offset']+args.N_pic//2], '+', c='r', ms=26, markeredgewidth=2, alpha=.5)
    ax.plot([j_pred+args.N_pic//2], [i_pred+args.N_pic//2], '+', c='b', ms=26, markeredgewidth=2, alpha=.5)

# %% [markdown]
# ## doing a saccade at the predicted the position of the target

# %%
print(data_fullfield.shape, retina_data.shape, label.shape)
# Out:
# (5000, 128, 128) torch.Size([5000, 1920]) torch.Size([5000])

# %%
accuracy = where.test_what(data_fullfield, pred_accuracy_colliculus, label)
print('mean accuracy =', accuracy.mean())
# Out:
# mean accuracy = 0.678

# %%
for idx in range(idx_start, idx_stop):
    fig = plt.figure(figsize = (15, 8))
    
    ax = fig.add_subplot(151)
    ax = where.display.show(ax, data_fullfield[idx, :, :])
    ax.set_title(f"i={positions[idx]['i_offset']}, j={positions[idx]['j_offset']}")
    
    ax = fig.add_subplot(152)
    data_retina = where.retina.retina(data_fullfield[idx, :, :])
    ax = where.retina.show(ax, where.retina.retina_invert(data_retina))
    ax.set_title(f"idx={idx}")
              
    ax = fig.add_subplot(153, projection='polar')
    ax.pcolor(where.retina.theta, where.retina.log_r, accuracy_colliculus[idx, :].numpy().reshape((args.N_azimuth, args.N_eccentricity)), cmap=plt.plasma())
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_title("True")

    ax = fig.add_subplot(154, projection='polar')
    ax.pcolor(where.retina.theta, where.retina.log_r, pred_accuracy_colliculus[idx, :].reshape((args.N_azimuth, args.N_eccentricity)), cmap=plt.plasma())
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_title("Predicted")

    i_pred, j_pred = where.index_prediction(pred_accuracy_colliculus[idx, :])
    ax = fig.add_subplot(155)                 
    ax = where.display.show(ax, where.extract(data_fullfield[idx, :, :], i_pred, j_pred), do_cross=False)
    result = '' if pred[idx]==label[idx].numpy() else 'FALSE'
    ax.set_title(f"pred={pred[idx]} acc={proba[idx,pred[idx]]:.2f} {result}")

# %% [markdown]
# testing on the test set:

# %%
correct = where.test()
print('Average accuracy on the test set = ', correct.mean())
# Out:
# Average accuracy on the test set =  0.6659999999999999

# %%
for data_fullfield, retina_data, accuracy_colliculus, digit_labels in where.loader_test:
    pred_accuracy_colliculus = where.pred_accuracy(retina_data)
    # use that predicted map to extract the foveal patch and classify the image
    correct = where.test_what(data_fullfield, pred_accuracy_colliculus, digit_labels)
    print(correct.mean())
# Out:
# 0.0979
# 0.1149
# 0.106
# 0.0987
# 0.1073
# 0.1076
# 0.0992
# 0.0967
# 0.1003
# 0.1007
# 0.1049
# 0.1018
# 0.1004
# 0.0992
# 0.1022
# 0.0992
# 0.1043
# 0.1023
# 0.1082
# 0.1084
# 0.1025
# 0.1045
# 0.1028
# 0.1045
# 0.1048
# 0.1082
# 0.1057
# 0.1099
# 0.1079
# 0.1146
# 0.0974
# 0.109
# 0.1078
# 0.1115
# 0.1118
# 0.118
# 0.1129
# 0.1047
# 0.1058
# 0.106
# 0.1255
# 0.1126
# 0.1104
# 0.1108
# 0.1036
# 0.1099
# 0.1074
# 0.1031
# 0.109
# 0.1007

# %%
data, label = next(iter(where.display.loader_test))
N_test = 100
positions, data_fullfield, retina_data, accuracy_colliculus = where.minibatch(data[:N_test, :])

pred_accuracy_colliculus = where.pred_accuracy(retina_data)

accuracy = where.test_what(data_fullfield, pred_accuracy_colliculus, label[:N_test])
print('mean accuracy =', accuracy.mean())
# Out:
# mean accuracy = 0.68

# %%
label.shape
# Out:
# torch.Size([5000])

# %%
data_fullfield, retina_data, accuracy_colliculus, digit_labels = next(iter(where.loader_test))
pred_accuracy_colliculus = where.pred_accuracy(retina_data)

accuracy = where.test_what(data_fullfield, pred_accuracy_colliculus, digit_labels.squeeze())
print('mean accuracy =', accuracy.mean())
# Out:
# mean accuracy = 0.59

# %%
digit_labels[1]
# Out:
# tensor([2.])

# %%
digit_labels.squeeze().shape
# Out:
# torch.Size([100])

# %%
for data_fullfield, retina_data, accuracy_colliculus, digit_labels in where.loader_test:
    pred_accuracy_colliculus = where.pred_accuracy(retina_data)
    # use that predicted map to extract the foveal patch and classify the image
    correct = where.test_what(data_fullfield, pred_accuracy_colliculus, digit_labels.squeeze())
    print(correct.mean())

# %% [markdown]
# # accuracy as a function of eccentricity

# %%
def test_eccentricities(N_eccentricities=9, ecc_max=.8):
    import torch
    from torch.autograd import Variable

    #eccentricities = args.N_pic / 2 * ecc_max * (1/args.rho)**(args.N_eccentricity - np.arange(N_eccentricities))
    eccentricities = np.linspace(where.args.offset_max, 0, N_eccentricities, endpoint=False)
    batch_size = 100 # where.args.test_batch_size # data.shape[0]
    from retina import get_data_loader
    loader_test = get_data_loader(batch_size=1, train=False, 
                                  mean=where.args.mean, std=where.args.std, seed=where.args.seed+10)
        
    accuracy_mean, accuracy_std = [], []
    for eccentricity in eccentricities:

        retina_data = np.zeros((batch_size, where.retina.vsize))
        labels = np.zeros((batch_size))
        data_fullfield = np.zeros((batch_size, where.args.N_pic, where.args.N_pic))        
        accuracy_colliculus = np.zeros((batch_size, where.args.N_azimuth * where.args.N_eccentricity))
        #positions =[]

        for i in range(batch_size):
            data, label = next(iter(loader_test))
            data_fullfield[i, :, :], i_offset, j_offset = where.display.draw(data[0, 0, :, :].numpy(), 
                                                                   radius=eccentricity)
            positions.append(dict(i_offset=i_offset, j_offset=j_offset))
            retina_data[i, :]  =  where.retina.retina(data_fullfield[i, :, :])
            labels[i] = label
        labels =  Variable(torch.FloatTensor(labels))
        retina_data =  Variable(torch.FloatTensor(retina_data))
        pred_accuracy_colliculus = where.pred_accuracy(retina_data)
        accuracy_ = where.test_what(data_fullfield, pred_accuracy_colliculus, labels.squeeze())
        accuracy_mean.append(accuracy_.mean())
        accuracy_std.append(accuracy_.std()) # TODO fit with beta distribution
        
    return eccentricities, np.array(accuracy_mean), np.array(accuracy_std)

N_eccentricities = 9
eccentricities, accuracy_mean, accuracy_std = test_eccentricities(N_eccentricities)
print('eccentricities=', eccentricities, ', accuracy_data=', accuracy_mean, ' +/- ', accuracy_std)
# Out:
# eccentricities= [35.         31.11111111 27.22222222 23.33333333 19.44444444 15.55555556
#  11.66666667  7.77777778  3.88888889] , accuracy_data= [0.24 0.53 0.74 0.72 0.78 0.83 0.92 0.86 0.78]  +/-  [0.42708313 0.49909919 0.43863424 0.44899889 0.4142463  0.3756328
#  0.2712932  0.34698703 0.4142463 ]

# %%
fig = plt.figure(figsize = (figwidth, figwidth/1.618))
ax_D = fig.add_subplot(1, 1, 1)
width = .8*np.abs(np.gradient(eccentricities)[0])
ax_D.bar(eccentricities, accuracy_mean, width=width, alpha = .5, label = 'One saccade')#yerr=accuracy_std, 
# TODO what instead? ax_D.bar(eccentricities, accuracy_data, alpha = .5, label = 'No saccade') #accuracy_map[27,27:55])
ax_D.plot([eccentricities.min()-width/2, eccentricities.max()+width/2], [0.1]*2, ':', c='k', label = 'Baseline')
plt.legend(loc='best')
#ax_D.set_title('Class accuracy', fontsize = 14)
ax_D.set_xlabel('Target eccentricity (pixels)', fontsize = 12)
ax_D.set_xticks(eccentricities)
ax_D.set_xticklabels(['%.1f' % d for  d in eccentricities])
ax_D.set_ylim([0,1]);

# %% [markdown]
# # summary

# %%
fig = plt.figure(figsize = (figwidth, figwidth/2.5))#1.618))
ax_A = plt.subplot(1, 4, 1) 
data_retina = where.retina.retina(data_fullfield[idx, :, :])
ax_A = where.retina.show(ax_A, where.retina.retina_invert(data_retina))
    
ax_B = plt.subplot(2, 4, 2, projection='polar', autoscale_on=False)
ax_B.pcolor(where.retina.theta, where.retina.log_r, accuracy_colliculus[idx, :].numpy().reshape((args.N_azimuth, args.N_eccentricity)))
ax_B.grid('off')
plt.title('True', fontsize = 14)
ax_B.set_yticklabels([])
ax_B.set_xticklabels([])

ax_Bb = plt.subplot(2, 4, 6, projection='polar')
ax_Bb.pcolor(where.retina.theta, where.retina.log_r, pred_accuracy_colliculus[idx, :].reshape((args.N_azimuth, args.N_eccentricity)))
ax_Bb.set_title('Predicted', fontsize = 14)
ax_Bb.set_yticklabels([])
ax_Bb.set_xticklabels([])


ax_C = plt.subplot(1, 4, 3)
data_fullfield = where.display.place_object(data[idx, 0, :, :].numpy(), 0, 0)
input_vector  =  where.retina.retina(data_fullfield)
ax_C = where.retina.show(ax_C, where.retina.retina_invert(input_vector))
i_pred, j_pred = where.index_prediction(pred_accuracy_colliculus[idx, :])
ax_A.arrow(64.5, 64.5, -i_pred, -j_pred, width=.3, color='r', head_width=4., length_includes_head=True, edgecolor='k')

ax_D = plt.subplot(1, 4, 4)
width = .8*np.abs(np.gradient(eccentricities)[0])
ax_D.bar(eccentricities, accuracy_mean, width=width, alpha = .5, label = 'One saccade')
ax_D.plot([eccentricities.min()-width/2, eccentricities.max()+width/2], [0.1]*2, ':', c='k', label = 'Baseline')
ax_D.plot([eccentricities.min()-width/2, eccentricities.max()+width/2], [acc_max]*2, ':', c='orange', label = 'Max')

plt.legend(loc='upper right')
ax_D.set_xlabel('Target eccentricity (pixels)', fontsize = 12)
ax_D.set_xticks(eccentricities)
ax_D.set_xticklabels(['%.1f' % d for  d in eccentricities])
ax_D.set_ylim([0,1])

for ax, text in [[ax_A, 'DIS'], [ax_C, 'SAC']]:
    ax.text(4, 15, text, fontsize=24,
          bbox={'facecolor':'white','alpha':1,'edgecolor':'none','pad':1},
          ha='left', va='center') 

offset = -.015
for ax, text, x_offset, y_offset in [[ax_A, 'A', offset, 1.15], [ax_B, 'B', -.25, 1.225], [ax_C, 'C', offset, 1.15], [ax_D, 'D', offset, 1.15]]:
    ax.text(x_offset, y_offset, '(' + text + ')', fontsize=24,
              bbox={'facecolor':'white','alpha':1,'edgecolor':'none','pad':1},
              ha='left', va='center', transform=ax.transAxes) 

# pos : [left, bottom, width, height] =    The new position of the in `.Figure` coordinates.    
plt.tight_layout()
ax_A.set_position([0.025, 0.1, .3, .45])
ax_B.set_position( [0.24, 0.375, .2, 0.2])
ax_Bb.set_position([0.24, 0.1, .2, 0.2])
ax_C.set_position([0.35, .1, .3, .45])
ax_D.set_position([0.65, .1, .3, .45])
fig.savefig(figname + '.pdf', bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# # post-processing

# %%
# !convert  -density {dpi_export} {figname}.pdf {figname}.jpg
# !convert  -density {dpi_export} {figname}.pdf {figname}.png
#!convert  -density {dpi_export} -resize 5400  -units pixelsperinch -flatten  -compress lzw  -depth 8 {fname}.pdf {fname}.tiff

# %%
from IPython.display import Image
Image('{figname}.png'.format(figname=figname))

# %%
# !ls  -l {figname}*
