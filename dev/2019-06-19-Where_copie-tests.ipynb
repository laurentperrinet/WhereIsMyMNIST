# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import TensorDataset, DataLoader

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
import sys
sys.path.append("../figures")

from where_copie import RetinaFill, CollFill, WhereShift, RetinaBackground, RetinaMask, RetinaWhiten 
from where_copie import RetinaTransform, WhereNet, CollTransform, MNIST, Normalize, WhereTrainer, Where

# %%
from main import init
args = init(filename='../data/2019-06-13')
args
# Out:
# {'w': 28,
#  'minibatch_size': 100,
#  'train_batch_size': 50000,
#  'test_batch_size': 10000,
#  'noise_batch_size': 1000,
#  'mean': 0.1307,
#  'std': 0.3081,
#  'N_pic': 128,
#  'offset_std': 30,
#  'offset_max': 34,
#  'noise': 0.75,
#  'contrast': 0.7,
#  'sf_0': 0.1,
#  'B_sf': 0.1,
#  'N_theta': 6,
#  'N_azimuth': 24,
#  'N_eccentricity': 10,
#  'N_phase': 2,
#  'rho': 1.41,
#  'bias_deconv': True,
#  'p_dropout': 0.0,
#  'dim1': 1000,
#  'dim2': 1000,
#  'lr': 0.005,
#  'do_adam': True,
#  'bn1_bn_momentum': 0.5,
#  'bn2_bn_momentum': 0.5,
#  'momentum': 0.3,
#  'epochs': 60,
#  'num_processes': 1,
#  'no_cuda': True,
#  'log_interval': 100,
#  'verbose': 1,
#  'filename': '../data/2019-06-13',
#  'seed': 2019,
#  'N_cv': 10,
#  'do_compute': True}

# %%
from retina_copie import Retina
retina = Retina(args)
# Out:
# ../tmp/retina_6_24_10_2_1.41_128_dico.npy
# Fichier retina_dico charge avec succes
# ../tmp/retina_6_24_10_2_1.41_128_transform.npy
# Fichier retina_transform charge avec succes

# %%
accuracy_map = np.loadtxt('../dev/AccuracyMap_MNIST_cnn_robust_what_0.1_0.1_1_0.7_60epoques_2019-06-12_16h11.txt', max_rows=55)

# %%
accuracy_map.min()
# Out:
# 0.0565

# %%
plt.imshow(accuracy_map)

# %%
_ = plt.plot(accuracy_map)

# %% [markdown]
# ## Unit tests

# %%
import math

# %%
i_offset = -18 #None #
j_offset = 18 #None #

# %%
args.contrast = 0.5

# %%
transform=transforms.Compose([
                               RetinaFill(N_pic=args.N_pic),
                               #WhereShift(args, theta=3*math.pi/4), 
                               #WhereShift(args, radius = 18), 
                               WhereShift(args, i_offset=i_offset, j_offset=j_offset),
                               RetinaBackground( contrast=args.contrast,
                                                 noise=args.noise,
                                                 sf_0=args.sf_0,
                                                 B_sf=args.B_sf),
                               RetinaMask(N_pic=args.N_pic),
                               RetinaWhiten(N_pic=args.N_pic),
                               RetinaTransform(retina.retina_transform_vector),
                               #Normalize()
                           ])

# %%
target_transform=transforms.Compose([
                               CollFill(accuracy_map=accuracy_map, N_pic=args.N_pic),
                               #WhereShift(args, theta=3*math.pi/4, baseline = 0.1),
                               #WhereShift(args, radius = 18, baseline = 0.1),
                               WhereShift(args, i_offset=i_offset, j_offset=j_offset, baseline = 0.1),
                               CollTransform(retina.colliculus_transform_vector),
                           ])

# %%
dataset_train = MNIST('../data',
                        train=True,
                        download=True,
                        transform=transform,
                        target_transform = target_transform,
                        )

# %%
len(dataset_train)
# Out:
# 60000

# %%
train_loader = torch.utils.data.DataLoader(dataset_train,
                                         batch_size=args.minibatch_size,
                                         shuffle=True)

# %%
dataset_test = MNIST('../data',
                        train=False,
                        download=True,
                        transform=transform,
                        target_transform = target_transform,
                        )

# %%
len(dataset_test)
# Out:
# 10000

# %%
test_loader = torch.utils.data.DataLoader(dataset_test,
                                         batch_size=args.minibatch_size,
                                         shuffle=True)

# %%
data, label = next(iter(train_loader))

# %%
data.shape
# Out:
# torch.Size([100, 2880])

# %%
print(len(data))
print(data[1])
print(len(data[1]))
print(data[1][1])
# Out:
# 100
# tensor([-0.0243,  0.0162,  0.0270,  ..., -3.7126,  1.7296,  1.2200],
#        dtype=torch.float64)
# 2880
# tensor(0.0162, dtype=torch.float64)

# %%
np.max((np.array([1, 2, 3]),np.array([3, 2, 1])), axis=0)
# Out:
# array([3, 2, 3])

# %%
#plt.imshow(data[i,:,:].detach().numpy())

# %%
label.shape
# Out:
# torch.Size([100, 240])

# %%
i = 4
_ = plt.plot(data[i,:].detach().numpy())
plt.show()
plt.imshow(data[i,:])
plt.show()
_ = plt.hist(data[i,:].detach().numpy().flatten(),31)


"""
i = 4
#_ = plt.plot(data[i,:].detach().numpy())
#plt.show()
print("dime", data[i,:].shape)
#plt.imshow(data[i,:])
plt.imshow(data[i,:].detach().numpy().reshape((128, 128)))
plt.show()
_ = plt.hist(data[i,:].detach().numpy().flatten(),31)
"""
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-207d579a6f8f> in <module>
#       2 _ = plt.plot(data[i,:].detach().numpy())
#       3 plt.show()
# ----> 4 plt.imshow(data[i,:])
#       5 plt.show()
#       6 _ = plt.hist(data[i,:].detach().numpy().flatten(),31)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2697         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2698         resample=resample, url=url, **({"data": data} if data is not
# -> 2699         None else {}), **kwargs)
#    2700     sci(__ret)
#    2701     return __ret
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5492                               resample=resample, **kwargs)
#    5493
# -> 5494         im.set_data(X)
#    5495         im.set_alpha(alpha)
#    5496         if im.get_clip_path() is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     636         if not (self._A.ndim == 2
#     637                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 638             raise TypeError("Invalid dimensions for image data")
#     639
#     640         if self._A.ndim == 3:
#
# TypeError: Invalid dimensions for image data

# %%
#plt.imshow(retina.retina_invert(data[i,:].detach().numpy()))
plt.plot(data[i,:].detach().numpy())

# %%
plt.plot(label[i,:].detach().numpy())

# %%
plt.imshow(retina.accuracy_invert(label[i,:].detach().numpy()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-96d10e4262a7> in <module>
# ----> 1 plt.imshow(retina.accuracy_invert(label[i,:].detach().numpy()))
#
# ~\PycharmProjects\WhereIsMyMNIST\dev\retina_copie.py in accuracy_invert(self, accuracy_colliculus)
#     702
#     703     def accuracy_invert(self, accuracy_colliculus):
# --> 704         im = self.colliculus_inverse @ accuracy_colliculus
#     705
#     706         return im.reshape(self.args.N_pic, self.args.N_pic)
#
# AttributeError: 'Retina' object has no attribute 'colliculus_inverse'

# %%
plt.hist(data[i,:].detach().numpy().flatten())
# Out:
# (array([   2.,   17.,   60.,  147.,  435., 1620.,  415.,  132.,   42.,
#           10.]), array([-11.688226  ,  -9.54273598,  -7.39724596,  -5.25175593,
#          -3.10626591,  -0.96077589,   1.18471413,   3.33020415,
#           5.47569417,   7.6211842 ,   9.76667422]), <a list of 10 Patch objects>)

# %% [markdown]
# ## WhereTrainer Class test

# %%
whereTrainer = WhereTrainer(args, generate_data=False)
# Out:
# ../tmp/retina_6_24_10_2_1.41_128_dico.npy
# Fichier retina_dico charge avec succes
# ../tmp/retina_6_24_10_2_1.41_128_transform.npy
# Fichier retina_transform charge avec succes
# BN1 is on
# BN2 is on

# %%
whereTrainer.model
# Out:
# WhereNet(
#   (bn1): Linear(in_features=2880, out_features=1000, bias=True)
#   (bn1_bn): BatchNorm1d(1000, eps=1e-05, momentum=0.5, affine=True, track_running_stats=True)
#   (bn2): Linear(in_features=1000, out_features=1000, bias=True)
#   (bn2_bn): BatchNorm1d(1000, eps=1e-05, momentum=0.5, affine=True, track_running_stats=True)
#   (bn3): Linear(in_features=1000, out_features=240, bias=True)
# )

# %% [markdown]
# ### Dataloader tests

# %% [markdown]
# #### TrainLoader

# %%
data, label = next(iter(whereTrainer.train_loader))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-eaf99a99bfca> in <module>
# ----> 1 data, label = next(iter(whereTrainer.train_loader))
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in <listcomp>(.0)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# ~\PycharmProjects\WhereIsMyMNIST\dev\where_copie.py in __getitem__(self, index)
#      46
#      47         if self.transform is not None:
# ---> 48             img = self.transform((img, index))
#      49
#      50         if self.target_transform is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, img)
#      59     def __call__(self, img):
#      60         for t in self.transforms:
# ---> 61             img = t(img)
#      62         return img
#      63
#
# ~\PycharmProjects\WhereIsMyMNIST\dev\where_copie.py in __call__(self, data)
#     341         pass
#     342     def __call__(self, data):
# --> 343         return Variable(torch.FloatTensor(data.astype('float')))
#     344
#     345 class FullfieldToFloatTensor:
#
# AttributeError: 'list' object has no attribute 'astype'

# %%
data_test, label_test = next(iter(train_loader))

# %%
len(whereTrainer.train_loader.dataset)
# Out:
# 60000

# %%
len(whereTrainer.test_loader.dataset)
# Out:
# 10000

# %%
i = 3
plt.imshow(whereTrainer.retina.retina_invert(data_test[i,:].detach().numpy()))
plt.show()
plt.imshow(whereTrainer.retina.accuracy_invert(label_test[i,:].detach().numpy()))
plt.show()

# %% [markdown]
# #### TestLoader

# %%
#data, data_fullfield, acc, acc_fullfield, labels = next(iter(whereTrainer.test_loader)) # # le 19.06, normal ?
data, data_fullfield = next(iter(whereTrainer.test_loader))
print(len(data))
print(len(data[1]))
print(len(data_fullfield))
print(len(data_fullfield[1]))
# Out:
# 2
# 100
# 5
# 100

# %%
for batch_idx, (data, data_fullfield, acc, acc_fullfield, labels) in enumerate(whereTrainer.test_loader):
    print(batch_idx)

# %%
i = 3
plt.plot(data[i,:].detach().numpy())
plt.plot(data_test[i,:].detach().numpy())
plt.show()
plt.plot(acc[i,:].detach().numpy())
plt.plot(label_test[i,:].detach().numpy())
plt.show()
plt.imshow(whereTrainer.retina.retina_invert(data[i,:].detach().numpy()))
plt.title(labels[i].detach().numpy())
plt.show()
plt.imshow(data_fullfield[i,:].detach().numpy())
plt.show()
plt.imshow(whereTrainer.retina.accuracy_invert(acc[i,:].detach().numpy()))
plt.show()
plt.imshow(acc_fullfield[i,:].detach().numpy())
plt.show()

# %% [markdown]
# ### Filters tests

# %%
data.shape
# Out:
# torch.Size([100, 2880])

# %%
acc.min()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-e931aade079b> in <module>
# ----> 1 acc.min()
#
# NameError: name 'acc' is not defined

# %%
data_float = data.float()

# %%
data_double = data_float.double()

# %%
data_np = data [i,:].detach().numpy()

# %%
data_float_np = data_float[i,:].detach().numpy()

# %%
data_double_np = data_double[i,:].detach().numpy()

# %%
i = 0
plt.plot(data[i,:].detach().numpy())
plt.plot(data_float[i,:].detach().numpy())
plt.show()
plt.imshow(whereTrainer.retina.retina_invert(data[i,:].detach().numpy()))
plt.show()
plt.imshow(whereTrainer.retina.retina_invert(data_float[i,:].detach().numpy()))
plt.show()
plt.imshow(whereTrainer.retina.retina_invert(data_double[i,:].detach().numpy()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-0fd596f13765> in <module>
#       3 plt.plot(data_float[i,:].detach().numpy())
#       4 plt.show()
# ----> 5 plt.imshow(whereTrainer.retina.retina_invert(data[i,:].detach().numpy()))
#       6 plt.show()
#       7 plt.imshow(whereTrainer.retina.retina_invert(data_float[i,:].detach().numpy()))
#
# NameError: name 'whereTrainer' is not defined

# %%
i = 0
diff = data_np - data_float_np
plt.plot(diff)
plt.show()
plt.imshow(whereTrainer.retina.retina_invert(data_np))
plt.show()
plt.imshow(whereTrainer.retina.retina_invert(data_np + 1e-10))
plt.show()
plt.imshow(whereTrainer.retina.retina_invert(data_np + diff))
plt.show()
plt.imshow(whereTrainer.retina.retina_invert(data_np + diff * 1e-5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-765fd5105bc7> in <module>
#       3 plt.plot(diff)
#       4 plt.show()
# ----> 5 plt.imshow(whereTrainer.retina.retina_invert(data_np))
#       6 plt.show()
#       7 plt.imshow(whereTrainer.retina.retina_invert(data_np + 1e-10))
#
# NameError: name 'whereTrainer' is not defined

# %%
whereTrainer.retina.retina_inverse_transform.shape
plt.plot(whereTrainer.retina.retina_inverse_transform[0,:])
#plt.plot(whereTrainer.retina.retina_inverse_transform.flatten())

# %%
i = 0
print(whereTrainer.retina.retina_transform_vector.shape)
filter_test = whereTrainer.retina.retina_transform_vector[i,:]
print(filter_test.shape)
print(sum(abs(filter_test) > 1e-3) / (128*128))
#plt.plot(whereTrainer.retina.retina_inverse_transform.flatten())
plt.show()
plt.imshow(filter_test.reshape((128, 128)))
plt.show()
plt.imshow(whereTrainer.retina.retina_transform[5,5,1,0,:].reshape((128, 128)))
# Out:
# (2880, 16384)
# (16384,)
# 0.03466796875

# %% [markdown]
# ### Model  test

# %%
output = whereTrainer.model(torch.FloatTensor(data.float()).to('cpu'))

# %%
output.shape

# %%
output.max()

# %%
loss_func = torch.nn.BCEWithLogitsLoss()
loss = loss_func(output, label)

# %%
whereTrainer.loss_func

# %%
whereTrainer.optimizer

# %%
if False:
    from where import train, test
    test(args, 
          whereTrainer.model, 
          "cpu", 
          whereTrainer.test_loader, 
          whereTrainer.loss_func) #, 
          #whereTrainer.optimizer, 
          #1)

# %%
if True:
    for epoch in range(1, args.epochs + 1):
        whereTrainer.train(epoch)
        whereTrainer.test()

# %%
from where import where_suffix
suffix = where_suffix(args)
model_path = '/tmp/where_model_{}.pt'.format(suffix)
torch.save(whereTrainer.model, model_path) 
print('Model saved at', model_path)

# %% [raw]
# if False:
#     torch.save( whereTrainer.model, '/tmp/20190607')
# else:
#     whereTrainer.model = torch.load('/tmp/20190607')

# %%
whereTrainer.test()

# %% [markdown]
# ## Where Tests

# %%
where = Where(args, generate_data=True, trainer=whereTrainer)
# Out:
# 2019-07-18 10:03:53.443519
# Training the What model
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-d5f823bce304> in <module>
# ----> 1 where = Where(args, generate_data=True, trainer=whereTrainer)
#
# ~\PycharmProjects\WhereIsMyMNIST\dev\where_copie.py in __init__(self, args, save, batch_load, force_training, model, train_loader, test_loader, generate_data, what_model, retina, trainer, save_model)
#     702         else:
#     703             print(datetime.datetime.now())
# --> 704             what = What(args) # trains the what_model if needed
#     705             self.what_model = what.model.to(self.device)
#     706             print(datetime.datetime.now())
#
# ~\PycharmProjects\WhereIsMyMNIST\figures\what.py in __init__(self, args, train_loader, test_loader, force, seed, model, robust)
#     312                 print("Training the What model")
#     313             for epoch in range(1, args.epochs + 1):
# --> 314                 self.trainer.train(epoch)
#     315                 self.trainer.test()
#     316             self.model = self.trainer.model
#
# ~\PycharmProjects\WhereIsMyMNIST\figures\what.py in train(self, epoch)
#     227
#     228     def train(self, epoch):
# --> 229         train(self.args, self.model, self.device, self.train_loader, self.loss_func, self.optimizer, epoch)
#     230
#     231     def test(self):
#
# ~\PycharmProjects\WhereIsMyMNIST\figures\what.py in train(args, model, device, train_loader, loss_function, optimizer, epoch)
#     234 def train(args, model, device, train_loader, loss_function, optimizer, epoch):
#     235     model.train()
# --> 236     for batch_idx, (data, target) in enumerate(train_loader):
#     237         data, target = data.to(device), target.to(device)
#     238         optimizer.zero_grad()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     580                 self.reorder_dict[idx] = batch
#     581                 continue
# --> 582             return self._process_next_batch(batch)
#     583
#     584     next = __next__  # Python 2 compatibility
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in _process_next_batch(self, batch)
#     606                 raise Exception("KeyError:" + batch.exc_msg)
#     607             else:
# --> 608                 raise batch.exc_type(batch.exc_msg)
#     609         return batch
#     610
#
# AttributeError: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\_utils\worker.py", line 99, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "C:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\_utils\worker.py", line 99, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "../figures\what.py", line 35, in __getitem__
#     img = self.transform((img, index))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\torchvision\transforms\transforms.py", line 61, in __call__
#     img = t(img)
#   File "../figures\what.py", line 84, in __call__
#     i_offset_f = np.random.randn() * self.args.what_offset_std
# AttributeError: 'EasyDict' object has no attribute 'what_offset_std'

# %%
where.test()

# %% [markdown]
# ## Dataset generation

# %%
if False:
    for i, (data, label) in enumerate(train_loader):
        print(i, (i+1) * args.minibatch_size)
        if i == 0:
            full_data = data
            full_label = label
        else:
            full_data = torch.cat((full_data, data), 0)
            full_label = torch.cat((full_label, label), 0)

# %%
dataset = TensorDataset(full_data, full_label)
data_loader = DataLoader(dataset, batch_size=args.minibatch_size)

# %%
full_data.shape

# %%
data, label = next(iter(data_loader))

# %%
data.shape

# %%
plt.plot(label[i,:].detach().numpy())

# %%
np.random.seed(26722)
np.random.randn()

# %%
from display import pe, minmax
minmax(-15, 10)
