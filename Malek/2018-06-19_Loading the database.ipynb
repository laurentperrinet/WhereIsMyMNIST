# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
from Where import init, Data

args = init(batch_size=16)
#args.batch_size=16
d = Data(args)
fig, ax = d.show()

# %% [markdown]
# # testing couples function

# %%
from Where import couples

import numpy as np
i_offset = np.random.randint(args.size)
j_offset = np.random.randint(args.size)
data, foo = next(iter(d.data_loader))
print (data.shape)  
idx = 0
data_full, a_data = couples(data[idx, 0, :, :], d.accuracy, i_offset, j_offset, size=args.size, contrast=1.)
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize=((13, 5)))
ax[0].imshow(data_full)

ax[1].imshow(a_data)
# Out:
# torch.Size([16, 1, 28, 28])
# [[ 0.   -0.25  0.  ]
#  [-0.25  1.   -0.25]
#  [ 0.   -0.25  0.  ]]

# %%
print('minmax', a_data.min(), a_data.max(), np.median(a_data) )
# Out:
# minmax 0.0145 0.9852 0.0974

# %%
d.data_loader
