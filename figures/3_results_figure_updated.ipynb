# %% [markdown]
# This notebook introduces the problem addressed in this paper:
#
#  - localizating an object in a large image
#  - foveation
#  - action (saccade)

# %%
#%run 0_parameters.ipynb

# %%
from where import Where
from what import WhatNet
from retina import Retina
import torch.nn.functional as F

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Training the Where network

# %%
# %ls -lh ../data/*pt
# Out:
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 13 22:14 ../data/2019-03-13_train.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 14 17:44 ../data/2019-03-14_b_train.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 14 06:17 ../data/2019-03-14_train.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 14 14:54 ../data/2019-03-14_train3.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 14 19:28 ../data/2019-03-14_train4.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 15 22:18 ../data/2019-03-15_train.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 15 15:31 ../data/2019-03-15_train_b.pt
# -rw-r--r--  1 laurentperrinet  staff   8.8M Mar 20 17:46 ../data/2019-03-16_train.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 19 00:19 ../data/2019-03-18_train.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 19 15:18 ../data/2019-03-19_bis_train.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 19 15:54 ../data/2019-03-19_train.pt
# -rw-r--r--  1 laurentperrinet  staff    12M Mar 27 16:30 ../data/2019-03-27_train.pt
# -rw-r--r--  1 laurentperrinet  staff    11M Mar 29 16:13 ../data/2019-03-29_train.pt
# -rw-r--r--  1 laurentperrinet  staff   5.7M Apr  8 23:09 ../data/2019-04-01_train.pt
# -rw-r--r--  1 laurentperrinet  staff   6.1M Apr  3 12:47 ../data/2019-04-03_train.pt
# -rw-r--r--  1 laurentperrinet  staff    16M Apr 25 17:17 ../data/2019-04-15_bis_train.pt
# -rw-r--r--  1 laurentperrinet  staff    16M Apr 15 14:28 ../data/2019-04-15_train.pt
# -rw-r--r--  1 laurentperrinet  staff    16M Apr 19 11:00 ../data/2019-04-16_train.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Mar 14 12:31 ../data/MNIST_cnn.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  1 09:09 ../data/MNIST_cnn_0.05_0.1_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  1 12:31 ../data/MNIST_cnn_0.06299605249474366_0.1_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 17 22:59 ../data/MNIST_cnn_0.07071067811865475_0.1_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 18 13:22 ../data/MNIST_cnn_0.07937005259840997_0.1_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 18 15:27 ../data/MNIST_cnn_0.08908987181403394_0.1_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 18 21:44 ../data/MNIST_cnn_0.11224620483093731_0.1_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 19 02:31 ../data/MNIST_cnn_0.12599210498948732_0.1_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 19 03:59 ../data/MNIST_cnn_0.14142135623730953_0.1_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  1 14:31 ../data/MNIST_cnn_0.15874010519681994_0.1_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  1 21:43 ../data/MNIST_cnn_0.1_0.05_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  1 23:53 ../data/MNIST_cnn_0.1_0.06299605249474366_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 19 08:43 ../data/MNIST_cnn_0.1_0.07071067811865475_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 17 21:39 ../data/MNIST_cnn_0.1_0.07937005259840997_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 19 10:48 ../data/MNIST_cnn_0.1_0.08908987181403394_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 19 10:49 ../data/MNIST_cnn_0.1_0.11224620483093731_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 19 10:49 ../data/MNIST_cnn_0.1_0.12599210498948732_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 19 10:49 ../data/MNIST_cnn_0.1_0.14142135623730953_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  2 02:31 ../data/MNIST_cnn_0.1_0.15874010519681994_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  2 16:09 ../data/MNIST_cnn_0.1_0.1_0.375_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  2 23:24 ../data/MNIST_cnn_0.1_0.1_0.4724703937105774_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 20 04:19 ../data/MNIST_cnn_0.1_0.1_0.5303300858899106_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 20 04:19 ../data/MNIST_cnn_0.1_0.1_0.5952753944880748_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 20 09:33 ../data/MNIST_cnn_0.1_0.1_0.6681740386052545_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  3 06:03 ../data/MNIST_cnn_0.1_0.1_0.75_0.35.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  3 07:04 ../data/MNIST_cnn_0.1_0.1_0.75_0.44097236746320556.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 20 18:15 ../data/MNIST_cnn_0.1_0.1_0.75_0.4949747468305832.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 20 18:57 ../data/MNIST_cnn_0.1_0.1_0.75_0.5555903681888698.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 20 18:58 ../data/MNIST_cnn_0.1_0.1_0.75_0.6236291026982375.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 17 21:39 ../data/MNIST_cnn_0.1_0.1_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 21 05:18 ../data/MNIST_cnn_0.1_0.1_0.75_0.7857234338165611.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 21 08:11 ../data/MNIST_cnn_0.1_0.1_0.75_0.8819447349264111.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 21 09:04 ../data/MNIST_cnn_0.1_0.1_0.75_0.9899494936611666.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  3 09:58 ../data/MNIST_cnn_0.1_0.1_0.75_1.1111807363777395.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  3 11:21 ../data/MNIST_cnn_0.1_0.1_0.75_1.4.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 20 17:23 ../data/MNIST_cnn_0.1_0.1_0.8418465362320298_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 20 17:57 ../data/MNIST_cnn_0.1_0.1_0.9449407874211548_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Apr 20 18:08 ../data/MNIST_cnn_0.1_0.1_1.0606601717798214_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  3 01:31 ../data/MNIST_cnn_0.1_0.1_1.1905507889761495_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  3 04:02 ../data/MNIST_cnn_0.1_0.1_1.5_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  2 02:30 ../data/MNIST_cnn_0.1_0.2_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M May  1 14:41 ../data/MNIST_cnn_0.2_0.1_0.75_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1.0_0.1_5epoques_2019-06-20_14h05.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1.0_0.2_5epoques_2019-06-20_13h58.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1.0_0.3_5epoques_2019-06-20_13h52.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1.0_0.4_5epoques_2019-06-20_13h46.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1.0_0.5_5epoques_2019-06-20_13h40.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1.0_0.6_5epoques_2019-06-20_13h34.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1.0_0.7_1epoques_2019-06-14_14h32.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1.0_0.7_5epoques_2019-06-14_15h00.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1.0_0.7_5epoques_2019-06-17_16h55.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1.0_0.7_5epoques_2019-06-19_11h50.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1.0_0.7_5epoques_2019-06-20_13h27.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1.0_0.7_60epoques_2019-06-17_10h20.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1.0_0.7_60epoques_2019-06-17_16h54.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1_0.7.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1_0.7_60epoques.pt
# -rw-r--r--  1 laurentperrinet  staff   1.7M Jul  4 14:43 ../data/MNIST_cnn_robust_what_0.1_0.1_1_0.7_60epoques_2019-06-13_10h47.pt
# -rw-r--r--  1 laurentperrinet  staff   6.1M Apr  8 16:34 ../data/debug_train.pt
# -rw-r--r--  1 laurentperrinet  staff   150M Apr 15 13:22 ../data/noisy-MNIST.pt

# %% [raw]
# import torch
# filename_dataset = '/tmp/dataset_train_0.100_0.100_1.000_0.300_15.000_30.000_6_16_8_2_1.410_128_50000.pt'
# loader_train  = torch.load(filename_dataset)
# data, label = next(iter(loader_train))
# print(data.shape)
# print(label.shape)

# %%
from main import init
#args = init(filename='debug')
#args = init(filename='../data/2019-03-19_bis')
args = init(filename='../data/2019-06-13')
#args = init(filename='../data/2019-03-29')

args.save_model = True
period = 10
args.sf_0 = 1/period
args.B_sf = 1/period
args.contrast = 0.7
args.offset_std = 30
'''args.bn1_bn_momentum = 0
args.bn2_bn_momentum = 0
args.p_dropout = 0.5
args.lr = 1e-4
args.dim1 = 1000
args.dim2 = 1000
args.epochs = 60
args.verbose = True
args.save_model = True'''
# Out:
# 'args.bn1_bn_momentum = 0\nargs.bn2_bn_momentum = 0\nargs.p_dropout = 0.5\nargs.lr = 1e-4\nargs.dim1 = 1000\nargs.dim2 = 1000\nargs.epochs = 60\nargs.verbose = True\nargs.save_model = True'

# %%
nb_saccades = 1
figname = '../paper/fig_result_contrast_{:.1f}_{}'.format(args.contrast, nb_saccades)
figname
# Out:
# '../paper/fig_result_contrast_0.7_1'

# %%
args
# Out:
# {'w': 28,
#  'minibatch_size': 100,
#  'train_batch_size': 50000,
#  'test_batch_size': 10000,
#  'noise_batch_size': 1000,
#  'mean': 0.1307,
#  'std': 0.3081,
#  'N_pic': 128,
#  'offset_std': 30,
#  'offset_max': 34,
#  'noise': 0.75,
#  'contrast': 0.7,
#  'sf_0': 0.1,
#  'B_sf': 0.1,
#  'N_theta': 6,
#  'N_azimuth': 24,
#  'N_eccentricity': 10,
#  'N_phase': 2,
#  'rho': 1.41,
#  'bias_deconv': True,
#  'p_dropout': 0.0,
#  'dim1': 1000,
#  'dim2': 1000,
#  'lr': 0.005,
#  'do_adam': True,
#  'bn1_bn_momentum': 0.5,
#  'bn2_bn_momentum': 0.5,
#  'momentum': 0.3,
#  'epochs': 60,
#  'num_processes': 1,
#  'no_cuda': True,
#  'log_interval': 100,
#  'verbose': 1,
#  'filename': '../data/2019-06-13',
#  'seed': 2019,
#  'N_cv': 10,
#  'do_compute': True,
#  'save_model': True}

# %%
if False:
    # !rm ../data/2019-04-05_train.pt

# %%
args.epochs = 60

# %%
#args.train_batch_size = 20
#args.test_batch_size = 20
#retina = Retina(args)
where = Where(args) #, generate_data=False) #False, save = False)

#filename_train = args.filename + '_train.pt'
#filename_train = "../data/2019-03-14_train4.pt"
#filename_train = "../data/2019-03-29.pt"
#%ls -lh {filename_train}
#%rm {filename_train}
#%rm  ../data/debug_train.pt

#where.train(filename_train)
# Out:
# /usr/local/lib/python3.7/site-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'what.WhatNet' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.7/site-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.7/site-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# Retina vectorizing...
# ok
# success
# Done vectorizing...
# Inversing retina transform...
# Done Inversing retina transform...
# Generating training dataset
# 0 100
# 1 200
# 2 300
# 3 400
# 4 500
# 5 600
# 6 700
# 7 800
# 8 900
# 9 1000
# 10 1100
# 11 1200
# 12 1300
# 13 1400
# 14 1500
# 15 1600
# 16 1700
# 17 1800
# 18 1900
# 19 2000
# 20 2100
# 21 2200
# 22 2300
# 23 2400
# 24 2500
# 25 2600
# 26 2700
# 27 2800
# 28 2900
# 29 3000
# 30 3100
# 31 3200
# 32 3300
# 33 3400
# 34 3500
# 35 3600
# 36 3700
# 37 3800
# 38 3900
# 39 4000
# 40 4100
# 41 4200
# 42 4300
# 43 4400
# 44 4500
# 45 4600
# 46 4700
# 47 4800
# 48 4900
# 49 5000
# 50 5100
# 51 5200
# 52 5300
# 53 5400
# 54 5500
# 55 5600
# 56 5700
# 57 5800
# 58 5900
# 59 6000
# 60 6100
# 61 6200
# 62 6300
# 63 6400
# 64 6500
# 65 6600
# 66 6700
# 67 6800
# 68 6900
# 69 7000
# 70 7100
# 71 7200
# 72 7300
# 73 7400
# 74 7500
# 75 7600
# 76 7700
# 77 7800
# 78 7900
# 79 8000
# 80 8100
# 81 8200
# 82 8300
# 83 8400
# 84 8500
# 85 8600
# 86 8700
# 87 8800
# 88 8900
# 89 9000
# 90 9100
# 91 9200
# 92 9300
# 93 9400
# 94 9500
# 95 9600
# 96 9700
# 97 9800
# 98 9900
# 99 10000
# 100 10100
# 101 10200
# 102 10300
# 103 10400
# 104 10500
# 105 10600
# 106 10700
# 107 10800
# 108 10900
# 109 11000
# 110 11100
# 111 11200
# 112 11300
# 113 11400
# 114 11500
# 115 11600
# 116 11700
# 117 11800
# 118 11900
# 119 12000
# 120 12100
# 121 12200
# 122 12300
# 123 12400
# 124 12500
# 125 12600
# 126 12700
# 127 12800
# 128 12900
# 129 13000
# 130 13100
# 131 13200
# 132 13300
# 133 13400
# 134 13500
# 135 13600
# 136 13700
# 137 13800
# 138 13900
# 139 14000
# 140 14100
# 141 14200
# 142 14300
# 143 14400
# 144 14500
# 145 14600
# 146 14700
# 147 14800
# 148 14900
# 149 15000
# 150 15100
# 151 15200
# 152 15300
# 153 15400
# 154 15500
# 155 15600
# 156 15700
# 157 15800
# 158 15900
# 159 16000
# 160 16100
# 161 16200
# 162 16300
# 163 16400
# 164 16500
# 165 16600
# 166 16700
# 167 16800
# 168 16900
# 169 17000
# 170 17100
# 171 17200
# 172 17300
# 173 17400
# 174 17500
# 175 17600
# 176 17700
# 177 17800
# 178 17900
# 179 18000
# 180 18100
# 181 18200
# 182 18300
# 183 18400
# 184 18500
# 185 18600
# 186 18700
# 187 18800
# 188 18900
# 189 19000
# 190 19100
# 191 19200
# 192 19300
# 193 19400
# 194 19500
# 195 19600
# 196 19700
# 197 19800
# 198 19900
# 199 20000
# 200 20100
# 201 20200
# 202 20300
# 203 20400
# 204 20500
# 205 20600
# 206 20700
# 207 20800
# 208 20900
# 209 21000
# 210 21100
# 211 21200
# 212 21300
# 213 21400
# 214 21500
# 215 21600
# 216 21700
# 217 21800
# 218 21900
# 219 22000
# 220 22100
# 221 22200
# 222 22300
# 223 22400
# 224 22500
# 225 22600
# 226 22700
# 227 22800
# 228 22900
# 229 23000
# 230 23100
# 231 23200
# 232 23300
# 233 23400
# 234 23500
# 235 23600
# 236 23700
# 237 23800
# 238 23900
# 239 24000
# 240 24100
# 241 24200
# 242 24300
# 243 24400
# 244 24500
# 245 24600
# 246 24700
# 247 24800
# 248 24900
# 249 25000
# 250 25100
# 251 25200
# 252 25300
# 253 25400
# 254 25500
# 255 25600
# 256 25700
# 257 25800
# 258 25900
# 259 26000
# 260 26100
# 261 26200
# 262 26300
# 263 26400
# 264 26500
# 265 26600
# 266 26700
# 267 26800
# 268 26900
# 269 27000
# 270 27100
# 271 27200
# 272 27300
# 273 27400
# 274 27500
# 275 27600
# 276 27700
# 277 27800
# 278 27900
# 279 28000
# 280 28100
# 281 28200
# 282 28300
# 283 28400
# 284 28500
# 285 28600
# 286 28700
# 287 28800
# 288 28900
# 289 29000
# 290 29100
# 291 29200
# 292 29300
# 293 29400
# 294 29500
# 295 29600
# 296 29700
# 297 29800
# 298 29900
# 299 30000
# 300 30100
# 301 30200
# 302 30300
# 303 30400
# 304 30500
# 305 30600
# 306 30700
# 307 30800
# 308 30900
# 309 31000
# 310 31100
# 311 31200
# 312 31300
# 313 31400
# 314 31500
# 315 31600
# 316 31700
# 317 31800
# 318 31900
# 319 32000
# 320 32100
# 321 32200
# 322 32300
# 323 32400
# 324 32500
# 325 32600
# 326 32700
# 327 32800
# 328 32900
# 329 33000
# 330 33100
# 331 33200
# 332 33300
# 333 33400
# 334 33500
# 335 33600
# 336 33700
# 337 33800
# 338 33900
# 339 34000
# 340 34100
# 341 34200
# 342 34300
# 343 34400
# 344 34500
# 345 34600
# 346 34700
# 347 34800
# 348 34900
# 349 35000
# 350 35100
# 351 35200
# 352 35300
# 353 35400
# 354 35500
# 355 35600
# 356 35700
# 357 35800
# 358 35900
# 359 36000
# 360 36100
# 361 36200
# 362 36300
# 363 36400
# 364 36500
# 365 36600
# 366 36700
# 367 36800
# 368 36900
# 369 37000
# 370 37100
# 371 37200
# 372 37300
# 373 37400
# 374 37500
# 375 37600
# 376 37700
# 377 37800
# 378 37900
# 379 38000
# 380 38100
# 381 38200
# 382 38300
# 383 38400
# 384 38500
# 385 38600
# 386 38700
# 387 38800
# 388 38900
# 389 39000
# 390 39100
# 391 39200
# 392 39300
# 393 39400
# 394 39500
# 395 39600
# 396 39700
# 397 39800
# 398 39900
# 399 40000
# 400 40100
# 401 40200
# 402 40300
# 403 40400
# 404 40500
# 405 40600
# 406 40700
# 407 40800
# 408 40900
# 409 41000
# 410 41100
# 411 41200
# 412 41300
# 413 41400
# 414 41500
# 415 41600
# 416 41700
# 417 41800
# 418 41900
# 419 42000
# 420 42100
# 421 42200
# 422 42300
# 423 42400
# 424 42500
# 425 42600
# 426 42700
# 427 42800
# 428 42900
# 429 43000
# 430 43100
# 431 43200
# 432 43300
# 433 43400
# 434 43500
# 435 43600
# 436 43700
# 437 43800
# 438 43900
# 439 44000
# 440 44100
# 441 44200
# 442 44300
# 443 44400
# 444 44500
# 445 44600
# 446 44700
# 447 44800
# 448 44900
# 449 45000
# 450 45100
# 451 45200
# 452 45300
# 453 45400
# 454 45500
# 455 45600
# 456 45700
# 457 45800
# 458 45900
# 459 46000
# 460 46100
# 461 46200
# 462 46300
# 463 46400
# 464 46500
# 465 46600
# 466 46700
# 467 46800
# 468 46900
# 469 47000
# 470 47100
# 471 47200
# 472 47300
# 473 47400
# 474 47500
# 475 47600
# 476 47700
# 477 47800
# 478 47900
# 479 48000
# 480 48100
# 481 48200
# 482 48300
# 483 48400
# 484 48500
# 485 48600
# 486 48700
# 487 48800
# 488 48900
# 489 49000
# 490 49100
# 491 49200
# 492 49300
# 493 49400
# 494 49500
# 495 49600
# 496 49700
# 497 49800
# 498 49900
# 499 50000
# 500 50100
# 501 50200
# 502 50300
# 503 50400
# 504 50500
# 505 50600
# 506 50700
# 507 50800
# 508 50900
# 509 51000
# 510 51100
# 511 51200
# 512 51300
# 513 51400
# 514 51500
# 515 51600
# 516 51700
# 517 51800
# 518 51900
# 519 52000
# 520 52100
# 521 52200
# 522 52300
# 523 52400
# 524 52500
# 525 52600
# 526 52700
# 527 52800
# 528 52900
# 529 53000
# 530 53100
# 531 53200
# 532 53300
# 533 53400
# 534 53500
# 535 53600
# 536 53700
# 537 53800
# 538 53900
# 539 54000
# 540 54100
# 541 54200
# 542 54300
# 543 54400
# 544 54500
# 545 54600
# 546 54700
# 547 54800
# 548 54900
# 549 55000
# 550 55100
# 551 55200
# 552 55300
# 553 55400
# 554 55500
# 555 55600
# 556 55700
# 557 55800
# 558 55900
# 559 56000
# 560 56100
# 561 56200
# 562 56300
# 563 56400
# 564 56500
# 565 56600
# 566 56700
# 567 56800
# 568 56900
# 569 57000
# 570 57100
# 571 57200
# 572 57300
# 573 57400
# 574 57500
# 575 57600
# 576 57700
# 577 57800
# 578 57900
# 579 58000
# 580 58100
# 581 58200
# 582 58300
# 583 58400
# 584 58500
# 585 58600
# 586 58700
# 587 58800
# 588 58900
# 589 59000
# 590 59100
# 591 59200
# 592 59300
# 593 59400
# 594 59500
# 595 59600
# 596 59700
# 597 59800
# 598 59900
# 599 60000
# Done!
# Generating testing dataset
# 0 100
# 1 200
# 2 300
# 3 400
# 4 500
# 5 600
# 6 700
# 7 800
# 8 900
# 9 1000
# 10 1100
# 11 1200
# 12 1300
# 13 1400
# 14 1500
# 15 1600
# 16 1700
# 17 1800
# 18 1900
# 19 2000
# 20 2100
# 21 2200
# 22 2300
# 23 2400
# 24 2500
# 25 2600
# 26 2700
# 27 2800
# 28 2900
# 29 3000
# 30 3100
# 31 3200
# 32 3300
# 33 3400
# 34 3500
# 35 3600
# 36 3700
# 37 3800
# 38 3900
# 39 4000
# 40 4100
# 41 4200
# 42 4300
# 43 4400
# 44 4500
# 45 4600
# 46 4700
# 47 4800
# 48 4900
# 49 5000
# 50 5100
# 51 5200
# 52 5300
# 53 5400
# 54 5500
# 55 5600
# 56 5700
# 57 5800
# 58 5900
# 59 6000
# 60 6100
# 61 6200
# 62 6300
# 63 6400
# 64 6500
# 65 6600
# 66 6700
# 67 6800
# 68 6900
# 69 7000
# 70 7100
# 71 7200
# 72 7300
# 73 7400
# 74 7500
# 75 7600
# 76 7700
# 77 7800
# 78 7900
# 79 8000
# 80 8100
# 81 8200
# 82 8300
# 83 8400
# 84 8500
# 85 8600
# 86 8700
# 87 8800
# 88 8900
# 89 9000
# 90 9100
# 91 9200
# 92 9300
# 93 9400
# 94 9500
# 95 9600
# 96 9700
# 97 9800
# 98 9900
# 99 10000
# Done!
# BN1 is on
# BN2 is on
# Train Epoch: 1/60 [0/60000 (0%)]	Loss: 0.708086
# Train Epoch: 1/60 [10000/60000 (17%)]	Loss: 0.370269
# Train Epoch: 1/60 [20000/60000 (33%)]	Loss: 0.357843
# Train Epoch: 1/60 [30000/60000 (50%)]	Loss: 0.357676
# Train Epoch: 1/60 [40000/60000 (67%)]	Loss: 0.356977
# Train Epoch: 1/60 [50000/60000 (83%)]	Loss: 0.363706
#
# Test set: Average loss: 0.3665
#
# Train Epoch: 2/60 [0/60000 (0%)]	Loss: 0.356648
# Train Epoch: 2/60 [10000/60000 (17%)]	Loss: 0.362841
# Train Epoch: 2/60 [20000/60000 (33%)]	Loss: 0.361054
# Train Epoch: 2/60 [30000/60000 (50%)]	Loss: 0.360114
# Train Epoch: 2/60 [40000/60000 (67%)]	Loss: 0.359024
# Train Epoch: 2/60 [50000/60000 (83%)]	Loss: 0.362055
#
# Test set: Average loss: 0.3676
#
# Train Epoch: 3/60 [0/60000 (0%)]	Loss: 0.363978
# Train Epoch: 3/60 [10000/60000 (17%)]	Loss: 0.355596
# Train Epoch: 3/60 [20000/60000 (33%)]	Loss: 0.362466
# Train Epoch: 3/60 [30000/60000 (50%)]	Loss: 0.353151
# Train Epoch: 3/60 [40000/60000 (67%)]	Loss: 0.361837
# Train Epoch: 3/60 [50000/60000 (83%)]	Loss: 0.359692
#
# Test set: Average loss: 0.3594
#
# Train Epoch: 4/60 [0/60000 (0%)]	Loss: 0.362549
# Train Epoch: 4/60 [10000/60000 (17%)]	Loss: 0.361002
# Train Epoch: 4/60 [20000/60000 (33%)]	Loss: 0.360243
# Train Epoch: 4/60 [30000/60000 (50%)]	Loss: 0.356657
# Train Epoch: 4/60 [40000/60000 (67%)]	Loss: 0.358906
# Train Epoch: 4/60 [50000/60000 (83%)]	Loss: 0.355604
#
# Test set: Average loss: 0.3735
#
# Train Epoch: 5/60 [0/60000 (0%)]	Loss: 0.355639
# Train Epoch: 5/60 [10000/60000 (17%)]	Loss: 0.361508
# Train Epoch: 5/60 [20000/60000 (33%)]	Loss: 0.354537
# Train Epoch: 5/60 [30000/60000 (50%)]	Loss: 0.359076
# Train Epoch: 5/60 [40000/60000 (67%)]	Loss: 0.351769
# Train Epoch: 5/60 [50000/60000 (83%)]	Loss: 0.351063
#
# Test set: Average loss: 0.3602
#
# Train Epoch: 6/60 [0/60000 (0%)]	Loss: 0.346631
# Train Epoch: 6/60 [10000/60000 (17%)]	Loss: 0.350670
# Train Epoch: 6/60 [20000/60000 (33%)]	Loss: 0.356102
# Train Epoch: 6/60 [30000/60000 (50%)]	Loss: 0.358723
# Train Epoch: 6/60 [40000/60000 (67%)]	Loss: 0.361539
# Train Epoch: 6/60 [50000/60000 (83%)]	Loss: 0.357716
#
# Test set: Average loss: 0.3594
#
# Train Epoch: 7/60 [0/60000 (0%)]	Loss: 0.357899
# Train Epoch: 7/60 [10000/60000 (17%)]	Loss: 0.359231
# Train Epoch: 7/60 [20000/60000 (33%)]	Loss: 0.352341
# Train Epoch: 7/60 [30000/60000 (50%)]	Loss: 0.352595
# Train Epoch: 7/60 [40000/60000 (67%)]	Loss: 0.354667
# Train Epoch: 7/60 [50000/60000 (83%)]	Loss: 0.354239
#
# Test set: Average loss: 0.3601
#
# Train Epoch: 8/60 [0/60000 (0%)]	Loss: 0.353218
# Train Epoch: 8/60 [10000/60000 (17%)]	Loss: 0.352888
# Train Epoch: 8/60 [20000/60000 (33%)]	Loss: 0.351597
# Train Epoch: 8/60 [30000/60000 (50%)]	Loss: 0.362151
# Train Epoch: 8/60 [40000/60000 (67%)]	Loss: 0.357911
# Train Epoch: 8/60 [50000/60000 (83%)]	Loss: 0.358171
#
# Test set: Average loss: 0.3602
#
# Train Epoch: 9/60 [0/60000 (0%)]	Loss: 0.344931
# Train Epoch: 9/60 [10000/60000 (17%)]	Loss: 0.353386
# Train Epoch: 9/60 [20000/60000 (33%)]	Loss: 0.359852
# Train Epoch: 9/60 [30000/60000 (50%)]	Loss: 0.352999
# Train Epoch: 9/60 [40000/60000 (67%)]	Loss: 0.351573
# Train Epoch: 9/60 [50000/60000 (83%)]	Loss: 0.356018
#
# Test set: Average loss: 0.3609
#
# Train Epoch: 10/60 [0/60000 (0%)]	Loss: 0.353500
# Train Epoch: 10/60 [10000/60000 (17%)]	Loss: 0.351056
# Train Epoch: 10/60 [20000/60000 (33%)]	Loss: 0.354594
# Train Epoch: 10/60 [30000/60000 (50%)]	Loss: 0.354560
# Train Epoch: 10/60 [40000/60000 (67%)]	Loss: 0.347645
# Train Epoch: 10/60 [50000/60000 (83%)]	Loss: 0.353779
#
# Test set: Average loss: 0.3575
#
# Train Epoch: 11/60 [0/60000 (0%)]	Loss: 0.355497
# Train Epoch: 11/60 [10000/60000 (17%)]	Loss: 0.349831
# Train Epoch: 11/60 [20000/60000 (33%)]	Loss: 0.358731
# Train Epoch: 11/60 [30000/60000 (50%)]	Loss: 0.355982
# Train Epoch: 11/60 [40000/60000 (67%)]	Loss: 0.352536
# Train Epoch: 11/60 [50000/60000 (83%)]	Loss: 0.353956
#
# Test set: Average loss: 0.3624
#
# Train Epoch: 12/60 [0/60000 (0%)]	Loss: 0.356474
# Train Epoch: 12/60 [10000/60000 (17%)]	Loss: 0.357544
# Train Epoch: 12/60 [20000/60000 (33%)]	Loss: 0.348764
# Train Epoch: 12/60 [30000/60000 (50%)]	Loss: 0.370357
# Train Epoch: 12/60 [40000/60000 (67%)]	Loss: 0.353544
# Train Epoch: 12/60 [50000/60000 (83%)]	Loss: 0.352151
#
# Test set: Average loss: 0.3691
#
# Train Epoch: 13/60 [0/60000 (0%)]	Loss: 0.354944
# Train Epoch: 13/60 [10000/60000 (17%)]	Loss: 0.355615
# Train Epoch: 13/60 [20000/60000 (33%)]	Loss: 0.359006
# Train Epoch: 13/60 [30000/60000 (50%)]	Loss: 0.356987
# Train Epoch: 13/60 [40000/60000 (67%)]	Loss: 0.356337
# Train Epoch: 13/60 [50000/60000 (83%)]	Loss: 0.358244
#
# Test set: Average loss: 0.3672
#
# Train Epoch: 14/60 [0/60000 (0%)]	Loss: 0.361868
# Train Epoch: 14/60 [10000/60000 (17%)]	Loss: 0.351722
# Train Epoch: 14/60 [20000/60000 (33%)]	Loss: 0.354534
# Train Epoch: 14/60 [30000/60000 (50%)]	Loss: 0.351787
# Train Epoch: 14/60 [40000/60000 (67%)]	Loss: 0.353960
# Train Epoch: 14/60 [50000/60000 (83%)]	Loss: 0.362992
#
# Test set: Average loss: 0.3597
#
# Train Epoch: 15/60 [0/60000 (0%)]	Loss: 0.347077
# Train Epoch: 15/60 [10000/60000 (17%)]	Loss: 0.363772
# Train Epoch: 15/60 [20000/60000 (33%)]	Loss: 0.351392
# Train Epoch: 15/60 [30000/60000 (50%)]	Loss: 0.352580
# Train Epoch: 15/60 [40000/60000 (67%)]	Loss: 0.351263
# Train Epoch: 15/60 [50000/60000 (83%)]	Loss: 0.352155
#
# Test set: Average loss: 0.3833
#
# Train Epoch: 16/60 [0/60000 (0%)]	Loss: 0.352391
# Train Epoch: 16/60 [10000/60000 (17%)]	Loss: 0.357642
# Train Epoch: 16/60 [20000/60000 (33%)]	Loss: 0.355741
# Train Epoch: 16/60 [30000/60000 (50%)]	Loss: 0.351952
# Train Epoch: 16/60 [40000/60000 (67%)]	Loss: 0.358439
# Train Epoch: 16/60 [50000/60000 (83%)]	Loss: 0.353629
#
# Test set: Average loss: 0.3601
#
# Train Epoch: 17/60 [0/60000 (0%)]	Loss: 0.353232
# Train Epoch: 17/60 [10000/60000 (17%)]	Loss: 0.353959
# Train Epoch: 17/60 [20000/60000 (33%)]	Loss: 0.364447
# Train Epoch: 17/60 [30000/60000 (50%)]	Loss: 0.353126
# Train Epoch: 17/60 [40000/60000 (67%)]	Loss: 0.353715
# Train Epoch: 17/60 [50000/60000 (83%)]	Loss: 0.350976
#
# Test set: Average loss: 0.3807
#
# Train Epoch: 18/60 [0/60000 (0%)]	Loss: 0.360217
# Train Epoch: 18/60 [10000/60000 (17%)]	Loss: 0.354535
# Train Epoch: 18/60 [20000/60000 (33%)]	Loss: 0.354700
# Train Epoch: 18/60 [30000/60000 (50%)]	Loss: 0.352437
# Train Epoch: 18/60 [40000/60000 (67%)]	Loss: 0.351233
# Train Epoch: 18/60 [50000/60000 (83%)]	Loss: 0.354373
#
# Test set: Average loss: 0.3695
#
# Train Epoch: 19/60 [0/60000 (0%)]	Loss: 0.349803
# Train Epoch: 19/60 [10000/60000 (17%)]	Loss: 0.356892
# Train Epoch: 19/60 [20000/60000 (33%)]	Loss: 0.361826
# Train Epoch: 19/60 [30000/60000 (50%)]	Loss: 0.346623
# Train Epoch: 19/60 [40000/60000 (67%)]	Loss: 0.352366
# Train Epoch: 19/60 [50000/60000 (83%)]	Loss: 0.357263
#
# Test set: Average loss: 0.3656
#
# Train Epoch: 20/60 [0/60000 (0%)]	Loss: 0.350731
# Train Epoch: 20/60 [10000/60000 (17%)]	Loss: 0.350626
# Train Epoch: 20/60 [20000/60000 (33%)]	Loss: 0.351030
# Train Epoch: 20/60 [30000/60000 (50%)]	Loss: 0.356636
# Train Epoch: 20/60 [40000/60000 (67%)]	Loss: 0.355522
# Train Epoch: 20/60 [50000/60000 (83%)]	Loss: 0.358162
#
# Test set: Average loss: 0.3585
#
# Train Epoch: 21/60 [0/60000 (0%)]	Loss: 0.357183
# Train Epoch: 21/60 [10000/60000 (17%)]	Loss: 0.350238
# Train Epoch: 21/60 [20000/60000 (33%)]	Loss: 0.356960
# Train Epoch: 21/60 [30000/60000 (50%)]	Loss: 0.353029
# Train Epoch: 21/60 [40000/60000 (67%)]	Loss: 0.352096
# Train Epoch: 21/60 [50000/60000 (83%)]	Loss: 0.355619
#
# Test set: Average loss: 0.3631
#
# Train Epoch: 22/60 [0/60000 (0%)]	Loss: 0.349169
# Train Epoch: 22/60 [10000/60000 (17%)]	Loss: 0.349850
# Train Epoch: 22/60 [20000/60000 (33%)]	Loss: 0.352274
# Train Epoch: 22/60 [30000/60000 (50%)]	Loss: 0.359526
# Train Epoch: 22/60 [40000/60000 (67%)]	Loss: 0.353795
# Train Epoch: 22/60 [50000/60000 (83%)]	Loss: 0.353343
#
# Test set: Average loss: 0.3580
#
# Train Epoch: 23/60 [0/60000 (0%)]	Loss: 0.349248
# Train Epoch: 23/60 [10000/60000 (17%)]	Loss: 0.357243
# Train Epoch: 23/60 [20000/60000 (33%)]	Loss: 0.351519
# Train Epoch: 23/60 [30000/60000 (50%)]	Loss: 0.350724
# Train Epoch: 23/60 [40000/60000 (67%)]	Loss: 0.353375
# Train Epoch: 23/60 [50000/60000 (83%)]	Loss: 0.351010
#
# Test set: Average loss: 0.3667
#
# Train Epoch: 24/60 [0/60000 (0%)]	Loss: 0.351779
# Train Epoch: 24/60 [10000/60000 (17%)]	Loss: 0.355498
# Train Epoch: 24/60 [20000/60000 (33%)]	Loss: 0.362769
# Train Epoch: 24/60 [30000/60000 (50%)]	Loss: 0.353352
# Train Epoch: 24/60 [40000/60000 (67%)]	Loss: 0.349613
# Train Epoch: 24/60 [50000/60000 (83%)]	Loss: 0.350460
#
# Test set: Average loss: 0.3770
#
# Train Epoch: 25/60 [0/60000 (0%)]	Loss: 0.346794
# Train Epoch: 25/60 [10000/60000 (17%)]	Loss: 0.353829
# Train Epoch: 25/60 [20000/60000 (33%)]	Loss: 0.350359
# Train Epoch: 25/60 [30000/60000 (50%)]	Loss: 0.356822
# Train Epoch: 25/60 [40000/60000 (67%)]	Loss: 0.354887
# Train Epoch: 25/60 [50000/60000 (83%)]	Loss: 0.348148
#
# Test set: Average loss: 0.3600
#
# Train Epoch: 26/60 [0/60000 (0%)]	Loss: 0.353485
# Train Epoch: 26/60 [10000/60000 (17%)]	Loss: 0.350087
# Train Epoch: 26/60 [20000/60000 (33%)]	Loss: 0.348176
# Train Epoch: 26/60 [30000/60000 (50%)]	Loss: 0.356048
# Train Epoch: 26/60 [40000/60000 (67%)]	Loss: 0.350882
# Train Epoch: 26/60 [50000/60000 (83%)]	Loss: 0.354340
#
# Test set: Average loss: 0.3599
#
# Train Epoch: 27/60 [0/60000 (0%)]	Loss: 0.359170
# Train Epoch: 27/60 [10000/60000 (17%)]	Loss: 0.351239
# Train Epoch: 27/60 [20000/60000 (33%)]	Loss: 0.352308
# Train Epoch: 27/60 [30000/60000 (50%)]	Loss: 0.353531
# Train Epoch: 27/60 [40000/60000 (67%)]	Loss: 0.348626
# Train Epoch: 27/60 [50000/60000 (83%)]	Loss: 0.355264
#
# Test set: Average loss: 0.3608
#
# Train Epoch: 28/60 [0/60000 (0%)]	Loss: 0.358438
# Train Epoch: 28/60 [10000/60000 (17%)]	Loss: 0.350151
# Train Epoch: 28/60 [20000/60000 (33%)]	Loss: 0.362928
# Train Epoch: 28/60 [30000/60000 (50%)]	Loss: 0.345941
# Train Epoch: 28/60 [40000/60000 (67%)]	Loss: 0.352242
# Train Epoch: 28/60 [50000/60000 (83%)]	Loss: 0.351083
#
# Test set: Average loss: 0.3643
#
# Train Epoch: 29/60 [0/60000 (0%)]	Loss: 0.347609
# Train Epoch: 29/60 [10000/60000 (17%)]	Loss: 0.354748
# Train Epoch: 29/60 [20000/60000 (33%)]	Loss: 0.347966
# Train Epoch: 29/60 [30000/60000 (50%)]	Loss: 0.352956
# Train Epoch: 29/60 [40000/60000 (67%)]	Loss: 0.351697
# Train Epoch: 29/60 [50000/60000 (83%)]	Loss: 0.358447
#
# Test set: Average loss: 0.3652
#
# Train Epoch: 30/60 [0/60000 (0%)]	Loss: 0.352305
# Train Epoch: 30/60 [10000/60000 (17%)]	Loss: 0.356733
# Train Epoch: 30/60 [20000/60000 (33%)]	Loss: 0.353310
# Train Epoch: 30/60 [30000/60000 (50%)]	Loss: 0.353993
# Train Epoch: 30/60 [40000/60000 (67%)]	Loss: 0.357691
# Train Epoch: 30/60 [50000/60000 (83%)]	Loss: 0.349133
#
# Test set: Average loss: 0.3600
#
# Train Epoch: 31/60 [0/60000 (0%)]	Loss: 0.353603
# Train Epoch: 31/60 [10000/60000 (17%)]	Loss: 0.357626
# Train Epoch: 31/60 [20000/60000 (33%)]	Loss: 0.348231
# Train Epoch: 31/60 [30000/60000 (50%)]	Loss: 0.353931
# Train Epoch: 31/60 [40000/60000 (67%)]	Loss: 0.347040
# Train Epoch: 31/60 [50000/60000 (83%)]	Loss: 0.354019
#
# Test set: Average loss: 0.3684
#
# Train Epoch: 32/60 [0/60000 (0%)]	Loss: 0.349359
# Train Epoch: 32/60 [10000/60000 (17%)]	Loss: 0.362091
# Train Epoch: 32/60 [20000/60000 (33%)]	Loss: 0.350518
# Train Epoch: 32/60 [30000/60000 (50%)]	Loss: 0.353846
# Train Epoch: 32/60 [40000/60000 (67%)]	Loss: 0.349784
# Train Epoch: 32/60 [50000/60000 (83%)]	Loss: 0.354455
#
# Test set: Average loss: 0.3674
#
# Train Epoch: 33/60 [0/60000 (0%)]	Loss: 0.354644
# Train Epoch: 33/60 [10000/60000 (17%)]	Loss: 0.358748
# Train Epoch: 33/60 [20000/60000 (33%)]	Loss: 0.345840
# Train Epoch: 33/60 [30000/60000 (50%)]	Loss: 0.356931
# Train Epoch: 33/60 [40000/60000 (67%)]	Loss: 0.351173
# Train Epoch: 33/60 [50000/60000 (83%)]	Loss: 0.357195
#
# Test set: Average loss: 0.3661
#
# Train Epoch: 34/60 [0/60000 (0%)]	Loss: 0.355350
# Train Epoch: 34/60 [10000/60000 (17%)]	Loss: 0.357741
# Train Epoch: 34/60 [20000/60000 (33%)]	Loss: 0.354732
# Train Epoch: 34/60 [30000/60000 (50%)]	Loss: 0.346596
# Train Epoch: 34/60 [40000/60000 (67%)]	Loss: 0.352944
# Train Epoch: 34/60 [50000/60000 (83%)]	Loss: 0.348734
#
# Test set: Average loss: 0.3759
#
# Train Epoch: 35/60 [0/60000 (0%)]	Loss: 0.352673
# Train Epoch: 35/60 [10000/60000 (17%)]	Loss: 0.352750
# Train Epoch: 35/60 [20000/60000 (33%)]	Loss: 0.350168
# Train Epoch: 35/60 [30000/60000 (50%)]	Loss: 0.358169
# Train Epoch: 35/60 [40000/60000 (67%)]	Loss: 0.355773
# Train Epoch: 35/60 [50000/60000 (83%)]	Loss: 0.351894
#
# Test set: Average loss: 0.3627
#
# Train Epoch: 36/60 [0/60000 (0%)]	Loss: 0.358753
# Train Epoch: 36/60 [10000/60000 (17%)]	Loss: 0.350065
# Train Epoch: 36/60 [20000/60000 (33%)]	Loss: 0.355453
# Train Epoch: 36/60 [30000/60000 (50%)]	Loss: 0.356044
# Train Epoch: 36/60 [40000/60000 (67%)]	Loss: 0.346547
# Train Epoch: 36/60 [50000/60000 (83%)]	Loss: 0.351623
#
# Test set: Average loss: 0.3735
#
# Train Epoch: 37/60 [0/60000 (0%)]	Loss: 0.350719
# Train Epoch: 37/60 [10000/60000 (17%)]	Loss: 0.356853
# Train Epoch: 37/60 [20000/60000 (33%)]	Loss: 0.350226
# Train Epoch: 37/60 [30000/60000 (50%)]	Loss: 0.350375
# Train Epoch: 37/60 [40000/60000 (67%)]	Loss: 0.359685
# Train Epoch: 37/60 [50000/60000 (83%)]	Loss: 0.354279
#
# Test set: Average loss: 0.3634
#
# Train Epoch: 38/60 [0/60000 (0%)]	Loss: 0.355390
# Train Epoch: 38/60 [10000/60000 (17%)]	Loss: 0.354241
# Train Epoch: 38/60 [20000/60000 (33%)]	Loss: 0.352637
# Train Epoch: 38/60 [30000/60000 (50%)]	Loss: 0.350430
# Train Epoch: 38/60 [40000/60000 (67%)]	Loss: 0.351763
# Train Epoch: 38/60 [50000/60000 (83%)]	Loss: 0.347805
#
# Test set: Average loss: 0.3595
#
# Train Epoch: 39/60 [0/60000 (0%)]	Loss: 0.348593
# Train Epoch: 39/60 [10000/60000 (17%)]	Loss: 0.348506
# Train Epoch: 39/60 [20000/60000 (33%)]	Loss: 0.355123
# Train Epoch: 39/60 [30000/60000 (50%)]	Loss: 0.352208
# Train Epoch: 39/60 [40000/60000 (67%)]	Loss: 0.355545
# Train Epoch: 39/60 [50000/60000 (83%)]	Loss: 0.349159
#
# Test set: Average loss: 0.3635
#
# Train Epoch: 40/60 [0/60000 (0%)]	Loss: 0.351264
# Train Epoch: 40/60 [10000/60000 (17%)]	Loss: 0.348367
# Train Epoch: 40/60 [20000/60000 (33%)]	Loss: 0.352075
# Train Epoch: 40/60 [30000/60000 (50%)]	Loss: 0.349946
# Train Epoch: 40/60 [40000/60000 (67%)]	Loss: 0.356596
# Train Epoch: 40/60 [50000/60000 (83%)]	Loss: 0.350384
#
# Test set: Average loss: 0.3647
#
# Train Epoch: 41/60 [0/60000 (0%)]	Loss: 0.353209
# Train Epoch: 41/60 [10000/60000 (17%)]	Loss: 0.362725
# Train Epoch: 41/60 [20000/60000 (33%)]	Loss: 0.352345
# Train Epoch: 41/60 [30000/60000 (50%)]	Loss: 0.349132
# Train Epoch: 41/60 [40000/60000 (67%)]	Loss: 0.347193
# Train Epoch: 41/60 [50000/60000 (83%)]	Loss: 0.355673
#
# Test set: Average loss: 0.3685
#
# Train Epoch: 42/60 [0/60000 (0%)]	Loss: 0.351274
# Train Epoch: 42/60 [10000/60000 (17%)]	Loss: 0.354197
# Train Epoch: 42/60 [20000/60000 (33%)]	Loss: 0.353885
# Train Epoch: 42/60 [30000/60000 (50%)]	Loss: 0.348855
# Train Epoch: 42/60 [40000/60000 (67%)]	Loss: 0.351623
# Train Epoch: 42/60 [50000/60000 (83%)]	Loss: 0.345998
#
# Test set: Average loss: 0.3683
#
# Train Epoch: 43/60 [0/60000 (0%)]	Loss: 0.348462
# Train Epoch: 43/60 [10000/60000 (17%)]	Loss: 0.352147
# Train Epoch: 43/60 [20000/60000 (33%)]	Loss: 0.354360
# Train Epoch: 43/60 [30000/60000 (50%)]	Loss: 0.356023
# Train Epoch: 43/60 [40000/60000 (67%)]	Loss: 0.351623
# Train Epoch: 43/60 [50000/60000 (83%)]	Loss: 0.356191
#
# Test set: Average loss: 0.3757
#
# Train Epoch: 44/60 [0/60000 (0%)]	Loss: 0.353757
# Train Epoch: 44/60 [10000/60000 (17%)]	Loss: 0.347292
# Train Epoch: 44/60 [20000/60000 (33%)]	Loss: 0.350597
# Train Epoch: 44/60 [30000/60000 (50%)]	Loss: 0.352202
# Train Epoch: 44/60 [40000/60000 (67%)]	Loss: 0.348424
# Train Epoch: 44/60 [50000/60000 (83%)]	Loss: 0.353769
#
# Test set: Average loss: 0.3687
#
# Train Epoch: 45/60 [0/60000 (0%)]	Loss: 0.354277
# Train Epoch: 45/60 [10000/60000 (17%)]	Loss: 0.354090
# Train Epoch: 45/60 [20000/60000 (33%)]	Loss: 0.350544
# Train Epoch: 45/60 [30000/60000 (50%)]	Loss: 0.353222
# Train Epoch: 45/60 [40000/60000 (67%)]	Loss: 0.349918
# Train Epoch: 45/60 [50000/60000 (83%)]	Loss: 0.343933
#
# Test set: Average loss: 0.3869
#
# Train Epoch: 46/60 [0/60000 (0%)]	Loss: 0.354562
# Train Epoch: 46/60 [10000/60000 (17%)]	Loss: 0.352963
# Train Epoch: 46/60 [20000/60000 (33%)]	Loss: 0.351269
# Train Epoch: 46/60 [30000/60000 (50%)]	Loss: 0.352809
# Train Epoch: 46/60 [40000/60000 (67%)]	Loss: 0.354624
# Train Epoch: 46/60 [50000/60000 (83%)]	Loss: 0.345966
#
# Test set: Average loss: 0.3826
#
# Train Epoch: 47/60 [0/60000 (0%)]	Loss: 0.351569
# Train Epoch: 47/60 [10000/60000 (17%)]	Loss: 0.353830
# Train Epoch: 47/60 [20000/60000 (33%)]	Loss: 0.355214
# Train Epoch: 47/60 [30000/60000 (50%)]	Loss: 0.351453
# Train Epoch: 47/60 [40000/60000 (67%)]	Loss: 0.346294
# Train Epoch: 47/60 [50000/60000 (83%)]	Loss: 0.353913
#
# Test set: Average loss: 0.3751
#
# Train Epoch: 48/60 [0/60000 (0%)]	Loss: 0.350157
# Train Epoch: 48/60 [10000/60000 (17%)]	Loss: 0.358222
# Train Epoch: 48/60 [20000/60000 (33%)]	Loss: 0.347875
# Train Epoch: 48/60 [30000/60000 (50%)]	Loss: 0.347107
# Train Epoch: 48/60 [40000/60000 (67%)]	Loss: 0.349565
# Train Epoch: 48/60 [50000/60000 (83%)]	Loss: 0.353284
#
# Test set: Average loss: 0.3738
#
# Train Epoch: 49/60 [0/60000 (0%)]	Loss: 0.354581
# Train Epoch: 49/60 [10000/60000 (17%)]	Loss: 0.349671
# Train Epoch: 49/60 [20000/60000 (33%)]	Loss: 0.355042
# Train Epoch: 49/60 [30000/60000 (50%)]	Loss: 0.349281
# Train Epoch: 49/60 [40000/60000 (67%)]	Loss: 0.353168
# Train Epoch: 49/60 [50000/60000 (83%)]	Loss: 0.347976
#
# Test set: Average loss: 0.3782
#
# Train Epoch: 50/60 [0/60000 (0%)]	Loss: 0.350807
# Train Epoch: 50/60 [10000/60000 (17%)]	Loss: 0.357130
# Train Epoch: 50/60 [20000/60000 (33%)]	Loss: 0.353983
# Train Epoch: 50/60 [30000/60000 (50%)]	Loss: 0.349396
# Train Epoch: 50/60 [40000/60000 (67%)]	Loss: 0.353459
# Train Epoch: 50/60 [50000/60000 (83%)]	Loss: 0.345343
#
# Test set: Average loss: 0.3679
#
# Train Epoch: 51/60 [0/60000 (0%)]	Loss: 0.348446
# Train Epoch: 51/60 [10000/60000 (17%)]	Loss: 0.352448
# Train Epoch: 51/60 [20000/60000 (33%)]	Loss: 0.350701
# Train Epoch: 51/60 [30000/60000 (50%)]	Loss: 0.350017
# Train Epoch: 51/60 [40000/60000 (67%)]	Loss: 0.352382
# Train Epoch: 51/60 [50000/60000 (83%)]	Loss: 0.349343
#
# Test set: Average loss: 0.3611
#
# Train Epoch: 52/60 [0/60000 (0%)]	Loss: 0.352871
# Train Epoch: 52/60 [10000/60000 (17%)]	Loss: 0.352198
# Train Epoch: 52/60 [20000/60000 (33%)]	Loss: 0.346570
# Train Epoch: 52/60 [30000/60000 (50%)]	Loss: 0.347835
# Train Epoch: 52/60 [40000/60000 (67%)]	Loss: 0.351736
# Train Epoch: 52/60 [50000/60000 (83%)]	Loss: 0.352683
#
# Test set: Average loss: 0.3687
#
# Train Epoch: 53/60 [0/60000 (0%)]	Loss: 0.355170
# Train Epoch: 53/60 [10000/60000 (17%)]	Loss: 0.354564
# Train Epoch: 53/60 [20000/60000 (33%)]	Loss: 0.348625
# Train Epoch: 53/60 [30000/60000 (50%)]	Loss: 0.354716
# Train Epoch: 53/60 [40000/60000 (67%)]	Loss: 0.355832
# Train Epoch: 53/60 [50000/60000 (83%)]	Loss: 0.349961
#
# Test set: Average loss: 0.3807
#
# Train Epoch: 54/60 [0/60000 (0%)]	Loss: 0.349431
# Train Epoch: 54/60 [10000/60000 (17%)]	Loss: 0.354254
# Train Epoch: 54/60 [20000/60000 (33%)]	Loss: 0.349951
# Train Epoch: 54/60 [30000/60000 (50%)]	Loss: 0.345461
# Train Epoch: 54/60 [40000/60000 (67%)]	Loss: 0.352008
# Train Epoch: 54/60 [50000/60000 (83%)]	Loss: 0.359262
#
# Test set: Average loss: 0.3789
#
# Train Epoch: 55/60 [0/60000 (0%)]	Loss: 0.352941
# Train Epoch: 55/60 [10000/60000 (17%)]	Loss: 0.355539
# Train Epoch: 55/60 [20000/60000 (33%)]	Loss: 0.351321
# Train Epoch: 55/60 [30000/60000 (50%)]	Loss: 0.348327
# Train Epoch: 55/60 [40000/60000 (67%)]	Loss: 0.348448
# Train Epoch: 55/60 [50000/60000 (83%)]	Loss: 0.352071
#
# Test set: Average loss: 0.3631
#
# Train Epoch: 56/60 [0/60000 (0%)]	Loss: 0.351264
# Train Epoch: 56/60 [10000/60000 (17%)]	Loss: 0.346657
# Train Epoch: 56/60 [20000/60000 (33%)]	Loss: 0.349799
# Train Epoch: 56/60 [30000/60000 (50%)]	Loss: 0.355223
# Train Epoch: 56/60 [40000/60000 (67%)]	Loss: 0.355883
# Train Epoch: 56/60 [50000/60000 (83%)]	Loss: 0.347176
#
# Test set: Average loss: 0.3847
#
# Train Epoch: 57/60 [0/60000 (0%)]	Loss: 0.348581
# Train Epoch: 57/60 [10000/60000 (17%)]	Loss: 0.354914
# Train Epoch: 57/60 [20000/60000 (33%)]	Loss: 0.345732
# Train Epoch: 57/60 [30000/60000 (50%)]	Loss: 0.350963
# Train Epoch: 57/60 [40000/60000 (67%)]	Loss: 0.354387
# Train Epoch: 57/60 [50000/60000 (83%)]	Loss: 0.348094
#
# Test set: Average loss: 0.4017
#
# Train Epoch: 58/60 [0/60000 (0%)]	Loss: 0.351006
# Train Epoch: 58/60 [10000/60000 (17%)]	Loss: 0.348544
# Train Epoch: 58/60 [20000/60000 (33%)]	Loss: 0.347320
# Train Epoch: 58/60 [30000/60000 (50%)]	Loss: 0.350914
# Train Epoch: 58/60 [40000/60000 (67%)]	Loss: 0.355488
# Train Epoch: 58/60 [50000/60000 (83%)]	Loss: 0.351699
#
# Test set: Average loss: 0.3822
#
# Train Epoch: 59/60 [0/60000 (0%)]	Loss: 0.355020
# Train Epoch: 59/60 [10000/60000 (17%)]	Loss: 0.349515
# Train Epoch: 59/60 [20000/60000 (33%)]	Loss: 0.349984
# Train Epoch: 59/60 [30000/60000 (50%)]	Loss: 0.357198
# Train Epoch: 59/60 [40000/60000 (67%)]	Loss: 0.344937
# Train Epoch: 59/60 [50000/60000 (83%)]	Loss: 0.347909
#
# Test set: Average loss: 0.3735
#
# Train Epoch: 60/60 [0/60000 (0%)]	Loss: 0.364278
# Train Epoch: 60/60 [10000/60000 (17%)]	Loss: 0.348901
# Train Epoch: 60/60 [20000/60000 (33%)]	Loss: 0.349223
# Train Epoch: 60/60 [30000/60000 (50%)]	Loss: 0.349384
# Train Epoch: 60/60 [40000/60000 (67%)]	Loss: 0.353210
# Train Epoch: 60/60 [50000/60000 (83%)]	Loss: 0.356232
#
# Test set: Average loss: 0.3739
#
# /tmp/where_model__0.1_0.1_0.75_0.7_30_34_6_24_10_2_1.41_128.pt
# Model saved at /tmp/where_model__0.1_0.1_0.75_0.7_30_34_6_24_10_2_1.41_128.pt

# %%
where.model
# Out:
# WhereNet(
#   (bn1): Linear(in_features=2880, out_features=1000, bias=True)
#   (bn1_bn): BatchNorm1d(1000, eps=1e-05, momentum=0.5, affine=True, track_running_stats=True)
#   (bn2): Linear(in_features=1000, out_features=1000, bias=True)
#   (bn2_bn): BatchNorm1d(1000, eps=1e-05, momentum=0.5, affine=True, track_running_stats=True)
#   (bn3): Linear(in_features=1000, out_features=240, bias=True)
# )

# %%
retina_data, accuracy_colliculus = next(iter(where.loader_train))

# %%
from where import Normalize
retina_data = Normalize()(retina_data.float())

# %%
i = 1
data_i = retina_data[i,:].float()
plt.plot(data_i.detach().numpy())
x = where.model.bn1(data_i)
plt.plot(x.detach().numpy())
x = F.relu(x)
plt.plot(x.detach().numpy())
plt.show()
x2 = where.model.bn2(x)
plt.plot(data_i.detach().numpy())
plt.plot(x2.detach().numpy())
x2 = F.relu(x2)
plt.plot(x2.detach().numpy())
plt.show()
x3 = where.model.bn3(x2)
plt.plot(data_i.detach().numpy())
plt.plot(x3.detach().numpy())
#plt.plot(where.model.bn1(retina_data.float())[i,:].detach().numpy())

# %%
import torch

output = torch.sigmoid(where.model(retina_data))
output_test = where.pred_accuracy(retina_data)

# %%
plt.plot(retina_data[i,:].detach().numpy())

# %%
plt.plot(output[i, :].detach().numpy())
plt.plot(output_test[i, :])
plt.plot(accuracy_colliculus[i, :].detach().numpy())

# %%
retina_data_test, retina_fullfield_test, accuracy_colliculus_test, accuracy_colliculus_fullfield_test, labels_test, i_shift, j_shift = next(iter(where.loader_test))
#(retina_data_test, retina_fullfield_test), (accuracy_colliculus_test, accuracy_colliculus_fullfield_test, labels_test, i_shift, j_shift) = next(iter(where.loader_test))

# %%
from what import WhatTrainer
data, label = next(iter(WhatTrainer(args).test_loader))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-e3cf82496320> in <module>
#       1 from what import WhatTrainer
# ----> 2 data, label = next(iter(WhatTrainer(args).test_loader))
#
# /usr/local/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# /usr/local/lib/python3.7/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# ~/research/ActiveVision/WhereIsMyMNIST/figures/what.py in __getitem__(self, index)
#      33
#      34         if self.transform is not None:
# ---> 35             img = self.transform((img, index))
#      36
#      37         if self.target_transform is not None:
#
# /usr/local/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      58
#      59     def __call__(self, img):
# ---> 60         for t in self.transforms:
#      61             img = t(img)
#      62         return img
#
# ~/research/ActiveVision/WhereIsMyMNIST/figures/what.py in __call__(self, sample_index)
#      82                 i_offset = int(i_offset_f)
#      83             else:  # self.i_offset is None and self.j_offset is None
# ---> 84                 i_offset_f = np.random.randn() * self.args.what_offset_std
#      85                 i_offset_f = minmax(i_offset_f, self.args.what_offset_max)
#      86                 i_offset = int(i_offset_f)
#
# AttributeError: 'EasyDict' object has no attribute 'what_offset_std'

# %%
_ = plt.plot(retina_fullfield_test[i,:].detach().numpy())

# %%
#plt.plot(data[i,:].detach().numpy())

# %%
plt.imshow(retina_fullfield_test[i,:])
plt.show()
plt.imshow(accuracy_colliculus_fullfield_test[i,:])

# %%
output = torch.sigmoid(where.model(retina_data_test.float()))

# %%
fig = plt.figure(figsize = (8, 8))
ax = fig.add_subplot(111, projection='polar')
ax.pcolor(where.retina.theta_grid, where.retina.log_r_grid, accuracy_colliculus_test[i, :].detach().numpy().reshape((args.N_azimuth, args.N_eccentricity)), cmap=plt.plasma())
ax.set_yticklabels([])
ax.set_xticklabels([])
ax.set_title("True")
# Out:
# Text(0.5, 1.05, 'True')

# %%
fig = plt.figure(figsize = (8, 8))
ax = fig.add_subplot(111, projection='polar')
ax.pcolor(where.retina.theta_grid, where.retina.log_r_grid, output[i, :].detach().numpy().reshape((args.N_azimuth, args.N_eccentricity)), cmap=plt.plasma())
ax.set_yticklabels([])
ax.set_xticklabels([])
ax.set_title("predicted")
# Out:
# Text(0.5, 1.05, 'predicted')

# %% [markdown]
# # Visualisation of some examples

# %%
i = 3
plt.plot(retina_data[i,:].detach().numpy())

# %%
fig = plt.figure(figsize = (8, 8))
ax = fig.add_subplot(111)
ax = where.retina.show(ax, where.retina.retina_invert(retina_data[i,:].detach().numpy()))

# %%
fig = plt.figure(figsize = (8, 8))
ax = fig.add_subplot(111, projection='polar')
ax.pcolor(where.retina.theta_grid, where.retina.log_r_grid, accuracy_colliculus[i, :].numpy().reshape((args.N_azimuth, args.N_eccentricity)), cmap=plt.plasma())
ax.set_yticklabels([])
ax.set_xticklabels([])
ax.set_title("True")
# Out:
# Text(0.5, 1.05, 'True')

# %%
retina_data
# Out:
# tensor([[ 0.2013,  0.2089,  0.2144,  ...,  0.3014, -0.7793,  0.0911],
#         [ 0.1994,  0.2089,  0.2087,  ...,  0.4675, -0.7852,  0.0041],
#         [ 0.1953,  0.1687,  0.1675,  ...,  0.2997, -0.8465,  0.0457],
#         ...,
#         [ 0.2105,  0.1963,  0.2029,  ...,  0.1267, -0.8342,  0.2059],
#         [ 0.1477,  0.2458,  0.2346,  ...,  0.4552, -0.8320,  0.1599],
#         [ 0.1806,  0.1560,  0.1764,  ...,  0.0842, -0.7958,  0.2458]])

# %%
min(accuracy_colliculus[3,:])
# Out:
# tensor(0.0508)

# %%
print(accuracy_colliculus.shape)
print(args.N_azimuth)
print(args.N_eccentricity) 

print(where.args.N_azimuth)
print(where.args.N_eccentricity)
# Out:
# torch.Size([100, 240])
# 24
# 10
# 24
# 10

# %% [markdown]
# ## knowing the target position

# %%
idx_start, idx_stop = 0, 20

# %%
#positions, data_fullfield, retina_data, accuracy_colliculus = where.minibatch(data[idx_start:idx_stop])
#positions, data_fullfield, retina_data, accuracy_colliculus = where.minibatch(None) #data[idx_start:idx_stop])

# %%
retina_data, data_fullfield, accuracy_colliculus, _, label, i_offset, j_offset = next(iter(where.loader_test))

# %%
plt.plot(retina_data[i,:].detach().numpy())
np.std(retina_data[i,:].detach().numpy())
# Out:
# 14.834848

# %%
plt.plot(accuracy_colliculus[i,:].detach().numpy())

# %%
plt.imshow(data_fullfield[2,:])

# %%
_ = plt.plot(data_fullfield[2,:].detach().numpy())
#data_fullfield *= 255

# %%
import numpy as np
Delta=0

#im = np.zeros((args.test_batch_size, args.w, args.w))
im = np.zeros((idx_stop, where.args.w, where.args.w))
for idx in range(idx_stop): #args.test_batch_size):
    #im[idx, :, :] = where.extract(data_fullfield[idx, :, :], positions[idx]['i_offset'], positions[idx]['j_offset'])
    im[idx, :, :] = where.extract(data_fullfield[idx+Delta, :, :], i_offset[idx+Delta], j_offset[idx+Delta])
proba = where.classify_what(im).detach().numpy()
pred = proba.argmax(axis=1)# get the index of the max log-probability
#acc = proba[:, pred]

print(pred)
label_n = label[idx_start+Delta:idx_stop+Delta].detach().numpy()
print(label_n)
print(np.mean(np.equal(pred, label_n)))

#.detach().numpy().mean() #(pred==label.numpy()).mean()
#print('Accuracy max (knowing the position)=', acc_max)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-5b2036978daa> in <module>
#       7     #im[idx, :, :] = where.extract(data_fullfield[idx, :, :], positions[idx]['i_offset'], positions[idx]['j_offset'])
#       8     im[idx, :, :] = where.extract(data_fullfield[idx+Delta, :, :], i_offset[idx+Delta], j_offset[idx+Delta])
# ----> 9 proba = where.classify_what(im).detach().numpy()
#      10 pred = proba.argmax(axis=1)# get the index of the max log-probability
#      11 #acc = proba[:, pred]
#
# ~/research/ActiveVision/WhereIsMyMNIST/figures/where.py in classify_what(self, im)
#     837             im = Variable(torch.FloatTensor(im[:, None, ::]))
#     838         with torch.no_grad():
# --> 839             output = self.what_model(im)
#     840
#     841         return F.softmax(output, dim=1) #np.exp(output) #
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# ~/research/ActiveVision/WhereIsMyMNIST/figures/what.py in forward(self, x)
#     162
#     163     def forward(self, x):
# --> 164         x = F.relu(self.conv1(x))
#     165         x = F.max_pool2d(x, 2, 2)
#     166         x = F.relu(self.conv2(x))
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     329     @weak_script_method
#     330     def forward(self, input):
# --> 331         if self.padding_mode == 'circular':
#     332             expanded_padding = ((self.padding[1] + 1) // 2, self.padding[1] // 2,
#     333                                 (self.padding[0] + 1) // 2, self.padding[0] // 2)
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     537                 return modules[name]
#     538         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 539             type(self).__name__, name))
#     540
#     541     def __setattr__(self, name, value):
#
# AttributeError: 'Conv2d' object has no attribute 'padding_mode'

# %% [markdown]
# ## Generate a noisy MNIST database

# %%
import numpy as np
import torch
from torch.utils.data import TensorDataset, DataLoader
from torch.autograd import Variable
import os

#im = np.zeros((args.test_batch_size, args.w, args.w))

from display import get_data_loader
filename_dataset = '../data/noisy-MNIST.pt'

if not os.path.isfile(filename_dataset):
    batch_size = 100
    loader_full = get_data_loader(batch_size=batch_size, train=True, mean=where.args.mean, std=where.args.std, seed=where.args.seed+1)
    im = np.zeros((where.args.train_batch_size, 1, where.args.w, where.args.w))
    im_label = np.zeros(where.args.train_batch_size, dtype = 'int')
    for idx, (data, label) in enumerate (loader_full):
        if idx % 10 == 0:
            print(idx * 100)
        if idx == 500:
            break
        for j in range(batch_size):
            data_fullfield_, i_offset, j_offset = where.display.draw(data[j, 0, :, :].numpy())
            extracted = where.extract(data_fullfield_, i_offset, j_offset)
            im[idx * batch_size + j, 0, :, :] = extracted.reshape(1, 28, 28)
            im_label[idx * batch_size + j] = label[j]
    im = Variable(torch.FloatTensor(im)).to(where.device)
    im_label = Variable(torch.LongTensor(im_label)).to(where.device)
    loader_train = DataLoader(TensorDataset(im, im_label), batch_size=100)
    torch.save(loader_train, filename_dataset)
#.detach().numpy().mean() #(pred==label.numpy()).mean()
#print('Accuracy max (knowing the position)=', acc_max)

# %%
if False:
    check_loader = torch.load(filename_dataset)
    im, label = next(iter(check_loader))
    im.shape
    i = 4
    plt.imshow(im[i,0,:,:])
    plt.title(label[i].detach().numpy())

# %%
idx = 1
plt.imshow(data_fullfield[idx,:,:])
print(i_offset[idx], j_offset[idx], label[idx])
plt.show()
#f = plt.plot(Normalize()(data_fullfield[idx,:,:]).detach().numpy())
f = plt.plot(data_fullfield[idx,:,:].detach().numpy())

# %%
idx_start, idx_stop = 0, 20

#from main_orig import init
#args = init()
#args.N_azimuth * args.N_eccentricity

# %%
for idx in range(idx_start, idx_stop):
    fig = plt.figure(figsize = (15, 8))
    
    ax = fig.add_subplot(141)
    ax = where.display.show(ax, data_fullfield[idx, :, :])
    #ax.set_title(f"i={positions[idx]['i_offset']}, j={positions[idx]['j_offset']}")
    ax.set_title(f"i={i_offset[idx]}, j={j_offset[idx]}")
    
    ax = fig.add_subplot(142)
    data_retina = where.retina.retina(data_fullfield[idx, :, :])
    ax = where.retina.show(ax, where.retina.retina_invert(data_retina))
    ax.set_title(f"idx={idx}")
              
    ax = fig.add_subplot(143, projection='polar')
    ax.pcolor(where.retina.theta_grid, where.retina.log_r_grid, accuracy_colliculus[idx, :].numpy().reshape((args.N_azimuth, args.N_eccentricity)), cmap=plt.plasma())
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_title("True")

    ax = fig.add_subplot(144)
    ax = where.display.show(ax, im[idx, :, :], do_cross=False)
    result = '' if pred[idx]==label[idx].numpy() else 'FALSE'
    ax.set_title(f"pred={pred[idx]} acc={proba[idx,pred[idx]]:.2f} {result}")

# %% [markdown]
# ## predicting the position of the target

# %%
pred_accuracy_colliculus = where.pred_accuracy(retina_data)
print('pred_accuracy_colliculus.shape=', pred_accuracy_colliculus.shape)

# %%
plt.plot(pred_accuracy_colliculus[2,:])

# %%
im_colliculus = where.retina.accuracy_invert(pred_accuracy_colliculus[0,:])
im_colliculus.shape

# %%
for idx in range(idx_start, idx_stop):
    fig = plt.figure(figsize = (15, 8))

    ax = fig.add_subplot(131, projection='polar')
    ax.pcolor(where.retina.theta_grid, where.retina.log_r_grid, pred_accuracy_colliculus[idx, :].reshape((args.N_azimuth, args.N_eccentricity)), cmap=plt.plasma())
    ax.set_title("Predicted")
    ax.set_yticklabels([])
    ax.set_xticklabels([])
              
    x = where.retina.accuracy_invert(pred_accuracy_colliculus[idx, :])
    ax = fig.add_subplot(132)
    ax.imshow(x, vmin=0, cmap=plt.plasma())
    ax.set_title("Pred visual space")
    
    i_pred, j_pred = where.index_prediction(pred_accuracy_colliculus[idx, :], do_shortcut=True)
    
    ax = fig.add_subplot(133)
    ax = where.display.show(ax, data_fullfield[idx, :, :])
    #ax.set_title(f"i={positions[idx]['i_offset']}/{i_pred}, j={positions[idx]['j_offset']}/{j_pred}")
    ax.set_title(f"i={i_offset[idx]}/{i_pred}, j={j_offset[idx]}/{j_pred}")
    #ax.plot([positions[idx]['j_offset']+args.N_pic//2], [positions[idx]['i_offset']+args.N_pic//2], '+', c='r', ms=26, markeredgewidth=2, alpha=.5)
    ax.plot([j_offset[idx]+args.N_pic//2], [i_offset[idx]+args.N_pic//2], '+', c='r', ms=26, markeredgewidth=2, alpha=.5)
    ax.plot([j_pred+args.N_pic//2], [i_pred+args.N_pic//2], '+', c='b', ms=26, markeredgewidth=2, alpha=.5)

# %% [markdown]
# ## doing a saccade at the predicted the position of the target

# %%
print(data_fullfield.shape, retina_data.shape, label.shape)

# %%
accuracy = where.test_what(data_fullfield, pred_accuracy_colliculus, label)
#print('mean accuracy =', accuracy.mean())
accuracy

# %%
where.what_class(data_fullfield, pred_accuracy_colliculus)

# %%
from display import minmax
pred_accuracy_colliculus = where.pred_accuracy(retina_data)
pred = where.what_class(data_fullfield, pred_accuracy_colliculus)
for idx in range(idx_start, idx_stop):
    fig = plt.figure(figsize = (15, 8))
    
    ax = fig.add_subplot(151)
    ax = where.display.show(ax, data_fullfield[idx, :, :])
    #ax.set_title(f"i={positions[idx]['i_offset']}, j={positions[idx]['j_offset']}")
    ax.set_title(f"i={i_offset[idx]}, j={j_offset[idx]}")
    
    ax = fig.add_subplot(152)
    data_retina = where.retina.retina(data_fullfield[idx, :, :])
    ax = where.retina.show(ax, where.retina.retina_invert(data_retina))
    ax.set_title(f"idx={idx}")
              
    ax = fig.add_subplot(153, projection='polar')
    ax.pcolor(where.retina.theta_grid, where.retina.log_r_grid, accuracy_colliculus[idx, :].numpy().reshape((args.N_azimuth, args.N_eccentricity)), cmap=plt.plasma())
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_title("True")

    ax = fig.add_subplot(154, projection='polar')
    ax.pcolor(where.retina.theta_grid, where.retina.log_r_grid, pred_accuracy_colliculus[idx, :].reshape((args.N_azimuth, args.N_eccentricity)), cmap=plt.plasma())
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_title("Predicted")

    #i_pred, j_pred = where.index_prediction(pred_accuracy_colliculus[idx, :])
    i_pred, j_pred = where.index_prediction(pred_accuracy_colliculus[idx, :], do_shortcut=True)
    ax = fig.add_subplot(155)                 
    ax = where.display.show(ax, where.extract(data_fullfield[idx, :, :], i_pred, j_pred), do_cross=False)
    result = '' if pred[idx]==label[idx].numpy() else 'FALSE'
    ax.set_title(f"pred={pred[idx]} acc={proba[idx,pred[idx]]:.2f} {result}")

# %% [markdown]
# testing on the test set:

# %% [markdown]
# # accuracy as a function of eccentricity

# %%
ecc_max=.8
N_eccentricities = args.N_eccentricity - 1
#eccentricities = args.N_pic / 2 * ecc_max * (1/args.rho)**(args.N_eccentricity - np.arange(N_eccentricities))
eccentricities = np.linspace(where.args.offset_max, 0, N_eccentricities, endpoint=False)

# %%
eccentricities

# %%
def test_eccentricities(N_eccentricities=9, ecc_max=.8, do_control=False):
    import torch
    from torchvision import datasets, transforms
    from torch.utils.data import TensorDataset, DataLoader
    from where import RetinaFill, CollFill, WhereShift, RetinaBackground, RetinaMask, FullfieldRetinaWhiten 
    from where import FullfieldRetinaTransform, FullfieldToFloatTensor, Normalize, MNIST
    from where import FullfieldCollTransform

    eccentricities = args.N_pic / 2 * ecc_max * (1/args.rho)**(args.N_eccentricity - np.arange(N_eccentricities))
    #eccentricities = np.linspace(where.args.offset_max, 0, N_eccentricities, endpoint=False)
    batch_size = 1000 #where.args.test_batch_size # data.shape[0]
    #from retina import get_data_loader
    #loader_test = get_data_loader(batch_size=1, train=False, 
    #                              mean=where.args.mean, std=where.args.std, seed=where.args.seed+10)
        
    accuracy_mean, accuracy_std = [], []
    for eccentricity in eccentricities:
        print(eccentricity)
        fullfield_transform = transforms.Compose([
            RetinaFill(N_pic=args.N_pic),
            WhereShift(args, radius = eccentricity),
            RetinaBackground(contrast=args.contrast,
                             noise=args.noise,
                             sf_0=args.sf_0,
                             B_sf=args.B_sf),
            RetinaMask(N_pic=args.N_pic),
            FullfieldRetinaWhiten(N_pic=args.N_pic),
            FullfieldRetinaTransform(where.retina.retina_transform_vector),
            FullfieldToFloatTensor(),
            #Normalize(fullfield=True)
            # transforms.Normalize((args.mean,), (args.std,))
        ])
        fullfield_target_transform=transforms.Compose([
                               CollFill(where.accuracy_map, keep_label = True, N_pic=args.N_pic, baseline=0.1),
                               WhereShift(args, baseline = 0.1, keep_label = True),
                               FullfieldCollTransform(where.retina.colliculus_transform_vector, keep_label = True),
                               FullfieldToFloatTensor(keep_label = True)
                           ])
        dataset = MNIST('../data',
                        train=False,
                        download=True,
                        transform=fullfield_transform,
                        target_transform=fullfield_target_transform,
                        )
        data_loader = DataLoader(dataset,
                                 batch_size=batch_size,
                                 shuffle=True)

        '''retina_data = np.zeros((batch_size, where.retina.vsize))
        labels = np.zeros((batch_size))
        data_fullfield = np.zeros((batch_size, where.args.N_pic, where.args.N_pic))        
        accuracy_colliculus = np.zeros((batch_size, where.args.N_azimuth * where.args.N_eccentricity))

        for i in range(batch_size):
            data, label = next(iter(loader_test))
            data_fullfield[i, :, :], i_offset, j_offset = where.display.draw(data[0, 0, :, :].numpy(), 
                                                                   radius=eccentricity)
            positions.append(dict(i_offset=i_offset, j_offset=j_offset))
            retina_data[i, :]  =  where.retina.retina(data_fullfield[i, :, :])
            labels[i] = label
        labels =  Variable(torch.FloatTensor(labels))
        retina_data =  Variable(torch.FloatTensor(retina_data))
        pred_accuracy_colliculus = where.pred_accuracy(retina_data)'''
        
        if nb_saccades >1 and not do_control:
            print('ok')
            accuracy = where.multi_test(nb_saccades, dataloader=data_loader)
            accuracy_mean.append(accuracy)
        else:
            data, acc = next(iter(data_loader))
            retina_data = data[0]
            data_fullfield = data[1]
            labels = acc[2]
            pred_accuracy_colliculus = where.pred_accuracy(retina_data)
            accuracy_ = where.test_what(data_fullfield, pred_accuracy_colliculus, labels.squeeze(), do_control=do_control)
            accuracy_mean.append(accuracy_.mean())
            accuracy_std.append(accuracy_.std()) # TODO fit with beta distribution'''
        
        
    return eccentricities, np.array(accuracy_mean), np.array(accuracy_std)

# %%
from where import where_suffix
import os
suffix = where_suffix(args)
file_path = '/tmp/eccentricity_accuracy_{}_{}.npy'.format(suffix, nb_saccades)
if True:
    eccentricities, accuracy_mean, accuracy_std = test_eccentricities(N_eccentricities)
    print('eccentricities=', eccentricities, ', accuracy_data=', accuracy_mean, ' +/- ', accuracy_std)
    eccentricities, ctl_accuracy_mean, ctl_accuracy_std = test_eccentricities(N_eccentricities, do_control=True)
    print('eccentricities=', eccentricities, ', ctl_accuracy_data=', ctl_accuracy_mean, ' +/- ', ctl_accuracy_std)
    np.save(file_path,[eccentricities, accuracy_mean, ctl_accuracy_mean])
else:
    data = np.load(file_path)
    eccentricities = data[0]
    accuracy_mean = data[1]
    ctl_accuracy_mean = data[2]

# %%
accuracy_mean

# %%
figwidth = 15
fig = plt.figure(figsize = (figwidth, figwidth/1.618))
ax_D = fig.add_subplot(1, 1, 1)
width = .8*np.abs(np.gradient(eccentricities)[0])
ax_D.bar(eccentricities, accuracy_mean, width=width, alpha = .7, label = 'One saccade')#yerr=accuracy_std, 
# TODO what instead? ax_D.bar(eccentricities, accuracy_data, alpha = .5, label = 'No saccade') #accuracy_map[27,27:55])
ax_D.bar(eccentricities, ctl_accuracy_mean, width=width, color='orange', alpha = .7, label = 'No saccade')
ax_D.plot([eccentricities.min()-width/2, eccentricities.max()+width/2], [0.1]*2, ':', c='k', label = 'Baseline')
plt.legend(loc='best')
#ax_D.set_title('Class accuracy', fontsize = 14)
ax_D.set_xlabel('Target eccentricity (pixels)', fontsize = 12)
ax_D.set_xticks(eccentricities)
ax_D.set_xticklabels(['%.1f' % d for  d in eccentricities])
ax_D.set_ylim([0,1]);

# %% [markdown]
# # summary

# %%
from where import WhereShift
idx = 13
fullfield = data_fullfield[idx, :, :]

fig = plt.figure(figsize = (figwidth, figwidth/2.5))#1.618))
ax_A = plt.subplot(1, 4, 1) 
data_retina = where.retina.retina(fullfield)
ax_A = where.retina.show(ax_A, where.retina.retina_invert(data_retina))
    
ax_B = plt.subplot(2, 4, 2, projection='polar', autoscale_on=False)
ax_B.pcolor(where.retina.theta_grid, where.retina.log_r_grid, accuracy_colliculus[idx, :].numpy().reshape((args.N_azimuth, args.N_eccentricity)))
ax_B.grid('off')
plt.title('True', fontsize = 14)
ax_B.set_yticklabels([])
ax_B.set_xticklabels([])

ax_Bb = plt.subplot(2, 4, 6, projection='polar')
ax_Bb.pcolor(where.retina.theta_grid, where.retina.log_r_grid, pred_accuracy_colliculus[idx, :].reshape((args.N_azimuth, args.N_eccentricity)))
ax_Bb.set_title('Predicted', fontsize = 14)
ax_Bb.set_yticklabels([])
ax_Bb.set_xticklabels([])

ax_C = plt.subplot(1, 4, 3)
#data_fullfield_ = where.display.place_object(data[idx, 0, :, :].numpy(), 0, 0)
i_pred, j_pred = where.index_prediction(pred_accuracy_colliculus[idx, :])
data_fullfield_ = WhereShift(args, i_offset=-i_pred, j_offset=-j_pred, baseline=0.5)((fullfield, 0)) 
input_vector  =  where.retina.retina(data_fullfield_)
ax_C = where.retina.show(ax_C, where.retina.retina_invert(input_vector))
#ax_A.arrow(64.5, 64.5, j_pred, i_pred, width=.3, color='r', head_width=4., length_includes_head=True, edgecolor='k')
ax_C.arrow(args.N_pic//2+j_pred+14, args.N_pic//2+i_pred+14, -j_pred, -i_pred, width=.3, color='r', head_width=4., length_includes_head=True, edgecolor='k')
ax_C.arrow(args.N_pic//2+j_pred+14, args.N_pic//2+i_pred-14, -j_pred, -i_pred, width=.3, color='r', head_width=4., length_includes_head=True, edgecolor='k')

ax_D = plt.subplot(1, 4, 4)
#width = .8*np.abs(np.gradient(eccentricities)[0])
width = .3*np.abs(eccentricities)
ax_D.bar(eccentricities, accuracy_mean, width=width, color='blue', alpha = .5, label = 'One saccade')
ax_D.bar(eccentricities, ctl_accuracy_mean, width=width, color='orange', alpha = .5, label = 'No saccade')
width = .5
ax_D.plot([eccentricities.min()-width/2, eccentricities.max()+width/2], [0.1]*2, ':', c='k', label = 'Baseline')
#ax_D.plot([eccentricities.min()-width/2, eccentricities.max()+width/2], [acc_max]*2, ':', c='k', label = 'Max')

plt.legend(loc='upper right')
ax_D.set_xlabel('Target eccentricity (pixels)', fontsize = 12)
ax_D.set_ylim([0,1])
ax_D.set_xscale('log')
ax_D.set_xticks(eccentricities)
ax_D.set_xticklabels(['%.1f' % d for  d in eccentricities])
ax_D.set_xlim([1.3,30])

for ax, text in [[ax_A, 'DIS'], [ax_C, 'SAC']]:
    ax.text(4, 15, text, fontsize=24,
          bbox={'facecolor':'white','alpha':1,'edgecolor':'none','pad':1},
          ha='left', va='center') 

offset = -.015
for ax, text, x_offset, y_offset in [[ax_A, 'A', offset, 1.15], [ax_B, 'B', -.25, 1.225], [ax_C, 'C', offset, 1.15], [ax_D, 'D', offset, 1.15]]:
    ax.text(x_offset, y_offset, '(' + text + ')', fontsize=24,
              bbox={'facecolor':'white','alpha':1,'edgecolor':'none','pad':1},
              ha='left', va='center', transform=ax.transAxes) 

# pos : [left, bottom, width, height] =    The new position of the in `.Figure` coordinates.    
plt.tight_layout()
ax_A.set_position([0.025, 0.1, .3, .45])
ax_B.set_position( [0.24, 0.375, .2, 0.2])
ax_Bb.set_position([0.24, 0.1, .2, 0.2])
ax_C.set_position([0.35, .1, .3, .45])
ax_D.set_position([0.65, .1, .3, .45])
fig.savefig(figname + '.pdf', bbox_inches='tight', pad_inches=0.1)

# %%
_ = plt.plot(fullfield.detach().numpy())

# %% [markdown]
# # post-processing

# %%
# !convert  -density {dpi_export} {figname}.pdf {figname}.jpg
# !convert  -density {dpi_export} {figname}.pdf {figname}.png
#!convert  -density {dpi_export} -resize 5400  -units pixelsperinch -flatten  -compress lzw  -depth 8 {fname}.pdf {fname}.tiff

# %%
from IPython.display import Image
Image('{figname}.png'.format(figname=figname))

# %%
# !ls  -l {figname}*

# %%
import os
suffix_what = "robust_{}_{}_{}_{}".format(args.sf_0, args.B_sf, args.noise, args.contrast)
accuracy_path = "../data/MNIST_accuracy_{}.npy".format(suffix_what)
if not os.path.isfile(accuracy_path):
    accuracy_map = np.load('../data/MNIST_accuracy.npy')
else:
    accuracy_map = np.load(accuracy_path)

# %%
plt.imshow(accuracy_map)
